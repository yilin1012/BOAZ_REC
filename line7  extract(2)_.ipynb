# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from selenium.webdriver.common.keys import Keys
import pandas as pd
import math
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import json

# %%
data = pd.read_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_(1)263url.csv')
data
# Out:
#        Unnamed: 0              상호명 상권업종중분류명     상권업종소분류명  \
# 0               0             이레식당       한식    한식/백반/한정식
# 1               1             피자스쿨    패스트푸드         피자전문
# 2               2             장터국밥       한식      해장국/감자탕
# 3               3  서울과학기술대학교제2학생식당    기타음식업  구내식당/자급식음식점
# 4               4        초밥&참치전문점연   일식/수산물        참치전문점
# ...           ...              ...      ...          ...
# 12182       12182             벚꽃스시   일식/수산물     음식점-초밥전문
# 12183       12183          생고기김치찌개       한식       갈비/삼겹살
# 12184       12184              피굽남       한식    한식/백반/한정식
# 12185       12185            왕십리곱창       한식     곱창/양구이전문
# 12186       12186            기찻길풍경       한식     곱창/양구이전문
#
#                        도로명주소               역명          거리  \
# 0        서울특별시 동작구 성대로31길 71         7호선 장승배기  252.070018
# 1         서울특별시 영등포구 대림로 247     7호선 대림(구로구청)  655.825278
# 2      서울특별시 도봉구 도봉로180나길 41          7호선 도봉산  490.786535
# 3          서울특별시 노원구 공릉로 232  7호선 공릉(서울과학기술대)  651.158559
# 4          서울특별시 광진구 능동로 179  7호선 어린이대공원(세종대)   59.203796
# ...                      ...              ...         ...
# 12182    서울특별시 동작구 상도로30길 40         7호선 장승배기  429.306668
# 12183  서울특별시 구로구 개봉로11길 18-1        7호선 광명사거리  588.584222
# 12184   서울특별시 중랑구 용마산로51길 45          7호선 용마산  471.931015
# 12185    서울특별시 중랑구 동일로163길 8           7호선 먹골  135.612799
# 12186    서울특별시 노원구 공릉로39길 21         7호선 태릉입구  461.771739
#
#                                      카카오url       역                  검색어
# 0      https://place.map.kakao.com/16821812    장승배기           장승배기역 이레식당
# 1      https://place.map.kakao.com/16300615      대림             대림역 피자스쿨
# 2                                       NaN     도봉산            도봉산역 장터국밥
# 3                                       NaN      공릉  공릉역 서울과학기술대학교제2학생식당
# 4      https://place.map.kakao.com/21086077  어린이대공원    어린이대공원역 초밥&참치전문점연
# ...                                     ...     ...                  ...
# 12182                                   NaN    장승배기           장승배기역 벚꽃스시
# 12183                                   NaN   광명사거리       광명사거리역 생고기김치찌개
# 12184                                   NaN     용마산             용마산역 피굽남
# 12185                                   NaN      먹골            먹골역 왕십리곱창
# 12186                                   NaN    태릉입구          태릉입구역 기찻길풍경
#
# [12187 rows x 10 columns]

# %%
data = data[["상호명","상권업종중분류명","상권업종소분류명","도로명주소","역명","거리","카카오url"]]
data["역"] = data["역명"].apply(lambda x : x.split(" ")[1])
data["역"] = data["역"].apply(lambda x : x.split("(")[0])
data["검색어"] = data.apply(lambda x : x["역"] + "역 " + str(x["상호명"]),axis=1)
data
# Out:
#                    상호명 상권업종중분류명     상권업종소분류명                  도로명주소  \
# 0                 이레식당       한식    한식/백반/한정식    서울특별시 동작구 성대로31길 71
# 1                 피자스쿨    패스트푸드         피자전문     서울특별시 영등포구 대림로 247
# 2                 장터국밥       한식      해장국/감자탕  서울특별시 도봉구 도봉로180나길 41
# 3      서울과학기술대학교제2학생식당    기타음식업  구내식당/자급식음식점      서울특별시 노원구 공릉로 232
# 4            초밥&참치전문점연   일식/수산물        참치전문점      서울특별시 광진구 능동로 179
# ...                ...      ...          ...                    ...
# 12182             벚꽃스시   일식/수산물     음식점-초밥전문    서울특별시 동작구 상도로30길 40
# 12183          생고기김치찌개       한식       갈비/삼겹살  서울특별시 구로구 개봉로11길 18-1
# 12184              피굽남       한식    한식/백반/한정식   서울특별시 중랑구 용마산로51길 45
# 12185            왕십리곱창       한식     곱창/양구이전문    서울특별시 중랑구 동일로163길 8
# 12186            기찻길풍경       한식     곱창/양구이전문    서울특별시 노원구 공릉로39길 21
#
#                     역명          거리                                카카오url  \
# 0             7호선 장승배기  252.070018  https://place.map.kakao.com/16821812
# 1         7호선 대림(구로구청)  655.825278  https://place.map.kakao.com/16300615
# 2              7호선 도봉산  490.786535                                   NaN
# 3      7호선 공릉(서울과학기술대)  651.158559                                   NaN
# 4      7호선 어린이대공원(세종대)   59.203796  https://place.map.kakao.com/21086077
# ...                ...         ...                                   ...
# 12182         7호선 장승배기  429.306668                                   NaN
# 12183        7호선 광명사거리  588.584222                                   NaN
# 12184          7호선 용마산  471.931015                                   NaN
# 12185           7호선 먹골  135.612799                                   NaN
# 12186         7호선 태릉입구  461.771739                                   NaN
#
#             역                  검색어
# 0        장승배기           장승배기역 이레식당
# 1          대림             대림역 피자스쿨
# 2         도봉산            도봉산역 장터국밥
# 3          공릉  공릉역 서울과학기술대학교제2학생식당
# 4      어린이대공원    어린이대공원역 초밥&참치전문점연
# ...       ...                  ...
# 12182    장승배기           장승배기역 벚꽃스시
# 12183   광명사거리       광명사거리역 생고기김치찌개
# 12184     용마산             용마산역 피굽남
# 12185      먹골            먹골역 왕십리곱창
# 12186    태릉입구          태릉입구역 기찻길풍경
#
# [12187 rows x 9 columns]

# %%
items = data["검색어"][263:]
items
# Out:
# 263         태릉입구역 여우떡볶이
# 264         건대입구역 이흥부족발
# 265        대림역 하들하들두부가게
# 266           건대입구역 포플러
# 267          마들역 금강산복아구
#               ...
# 12182        장승배기역 벚꽃스시
# 12183    광명사거리역 생고기김치찌개
# 12184          용마산역 피굽남
# 12185         먹골역 왕십리곱창
# 12186       태릉입구역 기찻길풍경
# Name: 검색어, Length: 11924, dtype: object

# %%
rating_df = pd.DataFrame(columns = ["UserID","ItemID","Rating","Timestamp"])
img_elem = pd.DataFrame(columns = ["ItemID","img_url"])
review_elem = pd.DataFrame(columns = ["ItemID", "review"])
user_review_id = {}
review_json = {}
image_json = {}

# %%
# 드라이버 구동
driver = webdriver.Chrome(executable_path='C:/Users/정예림/Desktop/추천시스템 프로젝트/chromedriver.exe')
# 창 크기 최대화
driver.maximize_window() 



count = 0
current = 0
indexing = 0
goal = len(items)
for item in items :
    current += 1
    print('진행상황 : ', current,'/',goal,sep="")
    # 리뷰가 없을 때의 코드
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    time.sleep(2)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        time.sleep(2)
        content_url = reviewbutton.get_attribute("href") 
        #상세보기 URL수집
        url = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').get_attribute('href')
        data.iloc[indexing,-3] = url
        print(url)
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        time.sleep(20)
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                try:
                    row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_ur}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)

                    time.sleep(1)
                except:
                    row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_url}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    time.sleep(1)

                
                    
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,500):
                time.sleep(3)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        try:
                            row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                            
                        except:
                            row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                        
                        
                            
        except:
            print("더 이상 리뷰 존재 X")
            driver.close()
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        data.iloc[indexing,-3] = None
        print("식당 존재 x")
    
    indexing += 1
# Out:
# 진행상황 : 1/11924
# 식당 존재
# https://place.map.kakao.com/21355812
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 2/11924
# 식당 존재 x
# 진행상황 : 3/11924
# 식당 존재
# https://place.map.kakao.com/159709846
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 4/11924
# 식당 존재 x
# 진행상황 : 5/11924
# 식당 존재
# https://place.map.kakao.com/21332074
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 6/11924
# 식당 존재 x
# 진행상황 : 7/11924
# 식당 존재
# https://place.map.kakao.com/16590861
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 8/11924
# 식당 존재
# https://place.map.kakao.com/469732154
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 9/11924
# 식당 존재 x
# 진행상황 : 10/11924
# 식당 존재 x
# 진행상황 : 11/11924
# 식당 존재
# https://place.map.kakao.com/10012761
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 12/11924
# 식당 존재
# https://place.map.kakao.com/17127063
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 13/11924
# 식당 존재 x
# 진행상황 : 14/11924
# 식당 존재
# https://place.map.kakao.com/344499073
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 15/11924
# 식당 존재
# https://place.map.kakao.com/1234837773
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 16/11924
# 식당 존재
# https://place.map.kakao.com/8101201
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 17/11924
# 식당 존재
# https://place.map.kakao.com/9532967
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 18/11924
# 식당 존재
# https://place.map.kakao.com/7922381
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 19/11924
# 식당 존재 x
# 진행상황 : 20/11924
# 식당 존재
# https://place.map.kakao.com/940411924
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 21/11924
# 식당 존재 x
# 진행상황 : 22/11924
# 식당 존재
# https://place.map.kakao.com/14601012
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 23/11924
# 식당 존재 x
# 진행상황 : 24/11924
# 식당 존재 x
# 진행상황 : 25/11924
# 식당 존재 x
# 진행상황 : 26/11924
# 식당 존재 x
# 진행상황 : 27/11924
# 식당 존재 x
# 진행상황 : 28/11924
# 식당 존재 x
# 진행상황 : 29/11924
# 식당 존재 x
# 진행상황 : 30/11924
# 식당 존재
# https://place.map.kakao.com/22137672
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 31/11924
# 식당 존재
# https://place.map.kakao.com/15424889
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 32/11924
# 식당 존재
# https://place.map.kakao.com/1751847609
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 33/11924
# 식당 존재
# https://place.map.kakao.com/1365585529
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 34/11924
# 식당 존재
# https://place.map.kakao.com/20559017
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 35/11924
# 식당 존재
# https://place.map.kakao.com/16379010
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 36/11924
# 식당 존재
# https://place.map.kakao.com/13270655
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 37/11924
# 식당 존재 x
# 진행상황 : 38/11924
# 식당 존재 x
# 진행상황 : 39/11924
# 식당 존재
# https://place.map.kakao.com/21243034
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 40/11924
# 식당 존재
# https://place.map.kakao.com/16532943
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 41/11924
# 식당 존재 x
# 진행상황 : 42/11924
# 식당 존재 x
# 진행상황 : 43/11924
# 식당 존재
# https://place.map.kakao.com/20633626
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 44/11924
# 식당 존재
# https://place.map.kakao.com/21232184
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 45/11924
# 식당 존재
# https://place.map.kakao.com/1270639008
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 46/11924
# 식당 존재
# https://place.map.kakao.com/832462058
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 47/11924
# 식당 존재
# https://place.map.kakao.com/870825710
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 48/11924
# 식당 존재
# https://place.map.kakao.com/2035438739
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 49/11924
# 식당 존재 x
# 진행상황 : 50/11924
# 식당 존재 x
# 진행상황 : 51/11924
# 식당 존재 x
# 진행상황 : 52/11924
# 식당 존재
# https://place.map.kakao.com/13293723
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 53/11924
# 식당 존재 x
# 진행상황 : 54/11924
# 식당 존재
# https://place.map.kakao.com/1356504452
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 55/11924
# 식당 존재
# https://place.map.kakao.com/973714733
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 56/11924
# 식당 존재
# https://place.map.kakao.com/23298946
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 57/11924
# 식당 존재
# https://place.map.kakao.com/1548565027
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 58/11924
# 식당 존재
# https://place.map.kakao.com/218159611
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 59/11924
# 식당 존재
# https://place.map.kakao.com/319853351
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 60/11924
# 식당 존재 x
# 진행상황 : 61/11924
# 식당 존재 x
# 진행상황 : 62/11924
# 식당 존재
# https://place.map.kakao.com/17361280
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 63/11924
# 식당 존재 x
# 진행상황 : 64/11924
# 식당 존재 x
# 진행상황 : 65/11924
# 식당 존재 x
# 진행상황 : 66/11924
# 식당 존재
# https://place.map.kakao.com/8142623
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 67/11924
# 식당 존재
# https://place.map.kakao.com/21234769
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 68/11924
# 식당 존재
# https://place.map.kakao.com/16555756
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 69/11924
# 식당 존재
# https://place.map.kakao.com/27401795
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 70/11924
# 식당 존재
# https://place.map.kakao.com/16533977
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 71/11924
# 식당 존재
# https://place.map.kakao.com/439541036
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 72/11924
# 식당 존재 x
# 진행상황 : 73/11924
# 식당 존재 x
# 진행상황 : 74/11924
# 식당 존재 x
# 진행상황 : 75/11924
# 식당 존재
# https://place.map.kakao.com/14526623
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 76/11924
# 식당 존재 x
# 진행상황 : 77/11924
# 식당 존재
# https://place.map.kakao.com/21527115
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 78/11924
# 식당 존재 x
# 진행상황 : 79/11924
# 식당 존재
# https://place.map.kakao.com/12783490
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 80/11924
# 식당 존재
# https://place.map.kakao.com/17079121
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 81/11924
# 식당 존재
# https://place.map.kakao.com/812839131
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 82/11924
# 식당 존재 x
# 진행상황 : 83/11924
# 식당 존재 x
# 진행상황 : 84/11924
# 식당 존재 x
# 진행상황 : 85/11924
# 식당 존재
# https://place.map.kakao.com/7985992
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 86/11924
# 식당 존재
# https://place.map.kakao.com/21424251
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 87/11924
# 식당 존재
# https://place.map.kakao.com/8835133
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 88/11924
# 식당 존재 x
# 진행상황 : 89/11924
# 식당 존재
# https://place.map.kakao.com/21442313
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 90/11924
# 식당 존재
# https://place.map.kakao.com/16558619
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 91/11924
# 식당 존재 x
# 진행상황 : 92/11924
# 식당 존재 x
# 진행상황 : 93/11924
# 식당 존재 x
# 진행상황 : 94/11924
# 식당 존재 x
# 진행상황 : 95/11924
# 식당 존재 x
# 진행상황 : 96/11924
# 식당 존재 x
# 진행상황 : 97/11924
# 식당 존재
# https://place.map.kakao.com/16328246
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 98/11924
# 식당 존재
# https://place.map.kakao.com/20380828
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 99/11924
# 식당 존재
# https://place.map.kakao.com/19358840
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 100/11924
# 식당 존재 x
# 진행상황 : 101/11924
# 식당 존재
# https://place.map.kakao.com/2132276101
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 102/11924
# 식당 존재 x
# 진행상황 : 103/11924
# 식당 존재
# https://place.map.kakao.com/16501198
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 104/11924
# 식당 존재
# https://place.map.kakao.com/15733546
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 105/11924
# 식당 존재
# https://place.map.kakao.com/11186250
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 106/11924
# 식당 존재
# https://place.map.kakao.com/8080507
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 107/11924
# 식당 존재
# https://place.map.kakao.com/24812697
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 108/11924
# 식당 존재 x
# 진행상황 : 109/11924
# 식당 존재
# https://place.map.kakao.com/8272445
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 110/11924
# 식당 존재 x
# 진행상황 : 111/11924
# 식당 존재
# https://place.map.kakao.com/2025356371
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 112/11924
# 식당 존재
# https://place.map.kakao.com/10557719
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 113/11924
# 식당 존재
# https://place.map.kakao.com/1044434257
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 114/11924
# 식당 존재
# https://place.map.kakao.com/7888145
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 115/11924
# 식당 존재
# https://place.map.kakao.com/23248859
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 116/11924
# 식당 존재
# https://place.map.kakao.com/20747538
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 117/11924
# 식당 존재
# https://place.map.kakao.com/2127120383
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 118/11924
# 식당 존재
# https://place.map.kakao.com/1084582076
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 119/11924
# 식당 존재
# https://place.map.kakao.com/16588905
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 120/11924
# 식당 존재
# https://place.map.kakao.com/83111528
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 121/11924
# 식당 존재
# https://place.map.kakao.com/1593142633
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 122/11924
# 식당 존재 x
# 진행상황 : 123/11924
# 식당 존재
# https://place.map.kakao.com/7886275
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 124/11924
# 식당 존재 x
# 진행상황 : 125/11924
# 식당 존재
# https://place.map.kakao.com/1302543058
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 126/11924
# 식당 존재
# https://place.map.kakao.com/16299128
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 127/11924
# 식당 존재 x
# 진행상황 : 128/11924
# 식당 존재
# https://place.map.kakao.com/995402415
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 129/11924
# 식당 존재 x
# 진행상황 : 130/11924
# 식당 존재
# https://place.map.kakao.com/19032412
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 131/11924
# 식당 존재 x
# 진행상황 : 132/11924
# 식당 존재 x
# 진행상황 : 133/11924
# 식당 존재
# https://place.map.kakao.com/35604373
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 134/11924
# 식당 존재 x
# 진행상황 : 135/11924
# 식당 존재 x
# 진행상황 : 136/11924
# 식당 존재 x
# 진행상황 : 137/11924
# 식당 존재
# https://place.map.kakao.com/13024787
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 138/11924
# 식당 존재 x
# 진행상황 : 139/11924
# 식당 존재
# https://place.map.kakao.com/16448062
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 140/11924
# 식당 존재
# https://place.map.kakao.com/18502776
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 141/11924
# 식당 존재 x
# 진행상황 : 142/11924
# 식당 존재
# https://place.map.kakao.com/27123487
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 143/11924
# 식당 존재 x
# 진행상황 : 144/11924
# 식당 존재 x
# 진행상황 : 145/11924
# 식당 존재
# https://place.map.kakao.com/1324770763
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 146/11924
# 식당 존재
# https://place.map.kakao.com/246552173
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 147/11924
# 식당 존재
# https://place.map.kakao.com/11092778
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 148/11924
# 식당 존재 x
# 진행상황 : 149/11924
# 식당 존재
# https://place.map.kakao.com/16878691
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 150/11924
# 식당 존재
# https://place.map.kakao.com/19666616
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 151/11924
# 식당 존재
# https://place.map.kakao.com/1934362415
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 152/11924
# 식당 존재 x
# 진행상황 : 153/11924
# 식당 존재
# https://place.map.kakao.com/24812376
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 154/11924
# 식당 존재
# https://place.map.kakao.com/134227537
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 155/11924
# 식당 존재 x
# 진행상황 : 156/11924
# 식당 존재 x
# 진행상황 : 157/11924
# 식당 존재 x
# 진행상황 : 158/11924
# 식당 존재
# https://place.map.kakao.com/914293828
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 159/11924
# 식당 존재 x
# 진행상황 : 160/11924
# 식당 존재
# https://place.map.kakao.com/12730661
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 161/11924
# 식당 존재
# https://place.map.kakao.com/17127063
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 162/11924
# 식당 존재 x
# 진행상황 : 163/11924
# 식당 존재 x
# 진행상황 : 164/11924
# 식당 존재
# https://place.map.kakao.com/333031201
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 165/11924
# 식당 존재 x
# 진행상황 : 166/11924
# 식당 존재 x
# 진행상황 : 167/11924
# 식당 존재
# https://place.map.kakao.com/1709745381
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 168/11924
# 식당 존재
# https://place.map.kakao.com/12323187
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 169/11924
# 식당 존재
# https://place.map.kakao.com/16526733
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 170/11924
# 식당 존재 x
# 진행상황 : 171/11924
# 식당 존재
# https://place.map.kakao.com/7866034
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 172/11924
# 식당 존재 x
# 진행상황 : 173/11924
# 식당 존재
# https://place.map.kakao.com/9618333
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 174/11924
# 식당 존재
# https://place.map.kakao.com/16790639
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 175/11924
# 식당 존재 x
# 진행상황 : 176/11924
# 식당 존재
# https://place.map.kakao.com/27229569
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 177/11924
# 식당 존재
# https://place.map.kakao.com/1287335856
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 178/11924
# 식당 존재 x
# 진행상황 : 179/11924
# 식당 존재 x
# 진행상황 : 180/11924
# 식당 존재
# https://place.map.kakao.com/21325321
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 181/11924
# 식당 존재 x
# 진행상황 : 182/11924
# 식당 존재
# https://place.map.kakao.com/27070075
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 183/11924
# 식당 존재
# https://place.map.kakao.com/1317042972
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 184/11924
# 식당 존재
# https://place.map.kakao.com/8143357
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 185/11924
# 식당 존재 x
# 진행상황 : 186/11924
# 식당 존재
# https://place.map.kakao.com/16733493
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 187/11924
# 식당 존재
# https://place.map.kakao.com/2029008550
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 188/11924
# 식당 존재 x
# 진행상황 : 189/11924
# 식당 존재
# https://place.map.kakao.com/27478521
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 190/11924
# 식당 존재 x
# 진행상황 : 191/11924
# 식당 존재
# https://place.map.kakao.com/23483653
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 192/11924
# 식당 존재
# https://place.map.kakao.com/1279359567
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 193/11924
# 식당 존재
# https://place.map.kakao.com/16051508
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 194/11924
# 식당 존재
# https://place.map.kakao.com/1177337965
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 195/11924
# 식당 존재 x
# 진행상황 : 196/11924
# 식당 존재 x
# 진행상황 : 197/11924
# 식당 존재 x
# 진행상황 : 198/11924
# 식당 존재
# https://place.map.kakao.com/23524280
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 199/11924
# 식당 존재
# https://place.map.kakao.com/25116623
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 200/11924
# 식당 존재 x
# 진행상황 : 201/11924
# 식당 존재
# https://place.map.kakao.com/17968198
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 202/11924
# 식당 존재 x
# 진행상황 : 203/11924
# 식당 존재
# https://place.map.kakao.com/17009887
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 204/11924
# 식당 존재 x
# 진행상황 : 205/11924
# 식당 존재
# https://place.map.kakao.com/18252704
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 206/11924
# 식당 존재 x
# 진행상황 : 207/11924
# 식당 존재
# https://place.map.kakao.com/508797207
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 208/11924
# 식당 존재
# https://place.map.kakao.com/1605351373
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 209/11924
# 식당 존재
# https://place.map.kakao.com/13578812
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 210/11924
# 식당 존재 x
# 진행상황 : 211/11924
# 식당 존재
# https://place.map.kakao.com/25461162
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 212/11924
# 식당 존재 x
# 진행상황 : 213/11924
# 식당 존재 x
# 진행상황 : 214/11924
# 식당 존재 x
# 진행상황 : 215/11924
# 식당 존재 x
# 진행상황 : 216/11924
# 식당 존재
# https://place.map.kakao.com/19175972
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 217/11924
# 식당 존재 x
# 진행상황 : 218/11924
# 식당 존재 x
# 진행상황 : 219/11924
# 식당 존재 x
# 진행상황 : 220/11924
# 식당 존재
# https://place.map.kakao.com/21131095
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 221/11924
# 식당 존재 x
# 진행상황 : 222/11924
# 식당 존재 x
# 진행상황 : 223/11924
# 식당 존재 x
# 진행상황 : 224/11924
# 식당 존재 x
# 진행상황 : 225/11924
# 식당 존재
# https://place.map.kakao.com/26874727
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 226/11924
# 식당 존재
# https://place.map.kakao.com/15648420
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 227/11924
# 식당 존재 x
# 진행상황 : 228/11924
# 식당 존재 x
# 진행상황 : 229/11924
# 식당 존재
# https://place.map.kakao.com/2123187868
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 230/11924
# 식당 존재
# https://place.map.kakao.com/1466478413
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 231/11924
# 식당 존재
# https://place.map.kakao.com/312347984
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 232/11924
# 식당 존재
# https://place.map.kakao.com/517418173
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 233/11924
# 식당 존재 x
# 진행상황 : 234/11924
# 식당 존재
# https://place.map.kakao.com/16793866
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 235/11924
# 식당 존재
# https://place.map.kakao.com/23557241
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 236/11924
# 식당 존재
# https://place.map.kakao.com/362201941
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 237/11924
# 식당 존재 x
# 진행상황 : 238/11924
# 식당 존재 x
# 진행상황 : 239/11924
# 식당 존재 x
# 진행상황 : 240/11924
# 식당 존재
# https://place.map.kakao.com/7889317
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 241/11924
# 식당 존재 x
# 진행상황 : 242/11924
# 식당 존재 x
# 진행상황 : 243/11924
# 식당 존재 x
# 진행상황 : 244/11924
# 식당 존재 x
# 진행상황 : 245/11924
# 식당 존재
# https://place.map.kakao.com/21656872
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 246/11924
# 식당 존재
# https://place.map.kakao.com/14632086
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 247/11924
# 식당 존재 x
# 진행상황 : 248/11924
# 식당 존재
# https://place.map.kakao.com/1968772249
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 249/11924
# 식당 존재
# https://place.map.kakao.com/13324303
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 250/11924
# 식당 존재 x
# 진행상황 : 251/11924
# 식당 존재 x
# 진행상황 : 252/11924
# 식당 존재
# https://place.map.kakao.com/1521767127
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 253/11924
# 식당 존재 x
# 진행상황 : 254/11924
# 식당 존재 x
# 진행상황 : 255/11924
# 식당 존재 x
# 진행상황 : 256/11924
# 식당 존재
# https://place.map.kakao.com/25044677
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 257/11924
# 식당 존재
# https://place.map.kakao.com/1662691655
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 258/11924
# 식당 존재 x
# 진행상황 : 259/11924
# 식당 존재 x
# 진행상황 : 260/11924
# 식당 존재
# https://place.map.kakao.com/24975782
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 261/11924
# 식당 존재 x
# 진행상황 : 262/11924
# 식당 존재
# https://place.map.kakao.com/27515257
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 263/11924
# 식당 존재
# https://place.map.kakao.com/2016732471
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 264/11924
# 식당 존재 x
# 진행상황 : 265/11924
# 식당 존재
# https://place.map.kakao.com/8594620
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 266/11924
# 식당 존재 x
# 진행상황 : 267/11924
# 식당 존재
# https://place.map.kakao.com/584274815
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 268/11924
# 식당 존재
# https://place.map.kakao.com/11748733
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 269/11924
# 식당 존재
# https://place.map.kakao.com/1863908043
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 270/11924
# 식당 존재 x
# 진행상황 : 271/11924
# 식당 존재
# https://place.map.kakao.com/178832371
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 272/11924
# 식당 존재
# https://place.map.kakao.com/12508558
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 273/11924
# 식당 존재 x
# 진행상황 : 274/11924
# 식당 존재
# https://place.map.kakao.com/26496245
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 275/11924
# 식당 존재
# https://place.map.kakao.com/1052243095
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 276/11924
# 식당 존재
# https://place.map.kakao.com/1894560025
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 277/11924
# 식당 존재 x
# 진행상황 : 278/11924
# 식당 존재
# https://place.map.kakao.com/25550171
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 279/11924
# 식당 존재
# https://place.map.kakao.com/440367256
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 280/11924
# 식당 존재 x
# 진행상황 : 281/11924
# 식당 존재 x
# 진행상황 : 282/11924
# 식당 존재 x
# 진행상황 : 283/11924
# 식당 존재
# https://place.map.kakao.com/864254714
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 284/11924
# 식당 존재
# https://place.map.kakao.com/23903855
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 285/11924
# 식당 존재 x
# 진행상황 : 286/11924
# 식당 존재 x
# 진행상황 : 287/11924
# 식당 존재 x
# 진행상황 : 288/11924
# 식당 존재
# https://place.map.kakao.com/1099161816
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 289/11924
# 식당 존재 x
# 진행상황 : 290/11924
# 식당 존재 x
# 진행상황 : 291/11924
# 식당 존재
# https://place.map.kakao.com/16906685
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 292/11924
# 식당 존재
# https://place.map.kakao.com/27382604
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 293/11924
# 식당 존재
# https://place.map.kakao.com/21234542
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 294/11924
# 식당 존재
# https://place.map.kakao.com/26617117
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 295/11924
# 식당 존재
# https://place.map.kakao.com/16706174
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 296/11924
# 식당 존재 x
# 진행상황 : 297/11924
# 식당 존재
# https://place.map.kakao.com/934488106
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 298/11924
# 식당 존재 x
# 진행상황 : 299/11924
# 식당 존재 x
# 진행상황 : 300/11924
# 식당 존재
# https://place.map.kakao.com/17253708
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 301/11924
# 식당 존재 x
# 진행상황 : 302/11924
# 식당 존재 x
# 진행상황 : 303/11924
# 식당 존재 x
# 진행상황 : 304/11924
# 식당 존재 x
# 진행상황 : 305/11924
# 식당 존재 x
# 진행상황 : 306/11924
# 식당 존재
# https://place.map.kakao.com/2124433280
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 307/11924
# 식당 존재
# https://place.map.kakao.com/10784395
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 308/11924
# 식당 존재
# https://place.map.kakao.com/26578284
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 309/11924
# 식당 존재 x
# 진행상황 : 310/11924
# 식당 존재
# https://place.map.kakao.com/16647370
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 311/11924
# 식당 존재 x
# 진행상황 : 312/11924
# 식당 존재
# https://place.map.kakao.com/20740721
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 313/11924
# 식당 존재
# https://place.map.kakao.com/23105993
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 314/11924
# 식당 존재 x
# 진행상황 : 315/11924
# 식당 존재 x
# 진행상황 : 316/11924
# 식당 존재 x
# 진행상황 : 317/11924
# 식당 존재 x
# 진행상황 : 318/11924
# 식당 존재 x
# 진행상황 : 319/11924
# 식당 존재 x
# 진행상황 : 320/11924
# 식당 존재 x
# 진행상황 : 321/11924
# 식당 존재 x
# 진행상황 : 322/11924
# 식당 존재
# https://place.map.kakao.com/19949847
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 323/11924
# 식당 존재 x
# 진행상황 : 324/11924
# 식당 존재
# https://place.map.kakao.com/1134204213
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 325/11924
# 식당 존재
# https://place.map.kakao.com/21536771
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 326/11924
# 식당 존재
# https://place.map.kakao.com/26453764
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 327/11924
# 식당 존재 x
# 진행상황 : 328/11924
# 식당 존재
# https://place.map.kakao.com/13595109
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 329/11924
# 식당 존재
# https://place.map.kakao.com/17000494
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 330/11924
# 식당 존재 x
# 진행상황 : 331/11924
# 식당 존재 x
# 진행상황 : 332/11924
# 식당 존재
# https://place.map.kakao.com/26628352
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 333/11924
# 식당 존재 x
# 진행상황 : 334/11924
# 식당 존재
# https://place.map.kakao.com/27513616
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 335/11924
# 식당 존재
# https://place.map.kakao.com/16590488
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 336/11924
# 식당 존재 x
# 진행상황 : 337/11924
# 식당 존재
# https://place.map.kakao.com/21403352
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 338/11924
# 식당 존재
# https://place.map.kakao.com/817075835
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 339/11924
# 식당 존재 x
# 진행상황 : 340/11924
# 식당 존재
# https://place.map.kakao.com/12118840
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 341/11924
# 식당 존재 x
# 진행상황 : 342/11924
# 식당 존재 x
# 진행상황 : 343/11924
# 식당 존재 x
# 진행상황 : 344/11924
# 식당 존재
# https://place.map.kakao.com/1194487940
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 345/11924
# 식당 존재
# https://place.map.kakao.com/278235079
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 346/11924
# 식당 존재
# https://place.map.kakao.com/22080248
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 347/11924
# 식당 존재 x
# 진행상황 : 348/11924
# 식당 존재 x
# 진행상황 : 349/11924
# 식당 존재
# https://place.map.kakao.com/1482453353
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 350/11924
# 식당 존재
# https://place.map.kakao.com/1881927967
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 351/11924
# 식당 존재 x
# 진행상황 : 352/11924
# 식당 존재 x
# 진행상황 : 353/11924
# 식당 존재
# https://place.map.kakao.com/1895030102
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 354/11924
# 식당 존재
# https://place.map.kakao.com/1846905391
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 355/11924
# 식당 존재
# https://place.map.kakao.com/190874505
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 356/11924
# 식당 존재
# https://place.map.kakao.com/1766284170
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 357/11924
# 식당 존재
# https://place.map.kakao.com/25693014
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 358/11924
# 식당 존재
# https://place.map.kakao.com/26889467
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 359/11924
# 식당 존재 x
# 진행상황 : 360/11924
# 식당 존재
# https://place.map.kakao.com/484006721
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 361/11924
# 식당 존재
# https://place.map.kakao.com/1466108122
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 362/11924
# 식당 존재
# https://place.map.kakao.com/13054214
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 363/11924
# 식당 존재
# https://place.map.kakao.com/515431946
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 364/11924
# 식당 존재
# https://place.map.kakao.com/16329867
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 365/11924
# 식당 존재
# https://place.map.kakao.com/21237444
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 366/11924
# 식당 존재 x
# 진행상황 : 367/11924
# 식당 존재
# https://place.map.kakao.com/1587831191
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 368/11924
# 식당 존재
# https://place.map.kakao.com/8572137
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 369/11924
# 식당 존재 x
# 진행상황 : 370/11924
# 식당 존재 x
# 진행상황 : 371/11924
# 식당 존재
# https://place.map.kakao.com/27360568
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 372/11924
# 식당 존재
# https://place.map.kakao.com/25068327
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 373/11924
# 식당 존재
# https://place.map.kakao.com/27188803
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 374/11924
# 식당 존재
# https://place.map.kakao.com/27161560
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 375/11924
# 식당 존재
# https://place.map.kakao.com/11420689
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 376/11924
# 식당 존재
# https://place.map.kakao.com/18565323
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 377/11924
# 식당 존재
# https://place.map.kakao.com/8459531
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 378/11924
# 식당 존재 x
# 진행상황 : 379/11924
# 식당 존재 x
# 진행상황 : 380/11924
# 식당 존재
# https://place.map.kakao.com/16735673
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 381/11924
# 식당 존재
# https://place.map.kakao.com/794484586
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 382/11924
# 식당 존재 x
# 진행상황 : 383/11924
# 식당 존재 x
# 진행상황 : 384/11924
# 식당 존재
# https://place.map.kakao.com/8613656
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 385/11924
# 식당 존재
# https://place.map.kakao.com/83205698
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 386/11924
# 식당 존재 x
# 진행상황 : 387/11924
# 식당 존재 x
# 진행상황 : 388/11924
# 식당 존재
# https://place.map.kakao.com/7870734
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 389/11924
# 식당 존재 x
# 진행상황 : 390/11924
# 식당 존재 x
# 진행상황 : 391/11924
# 식당 존재
# https://place.map.kakao.com/27501503
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 392/11924
# 식당 존재
# https://place.map.kakao.com/16063047
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 393/11924
# 식당 존재 x
# 진행상황 : 394/11924
# 식당 존재
# https://place.map.kakao.com/24212763
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 395/11924
# 식당 존재
# https://place.map.kakao.com/19014744
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 396/11924
# 식당 존재
# https://place.map.kakao.com/19410837
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 397/11924
# 식당 존재
# https://place.map.kakao.com/14659962
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 398/11924
# 식당 존재 x
# 진행상황 : 399/11924
# 식당 존재
# https://place.map.kakao.com/949874042
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 400/11924
# 식당 존재 x
# 진행상황 : 401/11924
# 식당 존재
# https://place.map.kakao.com/27347544
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 402/11924
# 식당 존재
# https://place.map.kakao.com/25160372
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 403/11924
# 식당 존재
# https://place.map.kakao.com/16711198
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 404/11924
# 식당 존재
# https://place.map.kakao.com/19299929
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 405/11924
# 식당 존재 x
# 진행상황 : 406/11924
# 식당 존재
# https://place.map.kakao.com/26633457
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 407/11924
# 식당 존재
# https://place.map.kakao.com/27311199
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 408/11924
# 식당 존재
# https://place.map.kakao.com/20744243
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 409/11924
# 식당 존재 x
# 진행상황 : 410/11924
# 식당 존재 x
# 진행상황 : 411/11924
# 식당 존재 x
# 진행상황 : 412/11924
# 식당 존재
# https://place.map.kakao.com/26556131
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 413/11924
# 식당 존재
# https://place.map.kakao.com/16271271
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 414/11924
# 식당 존재 x
# 진행상황 : 415/11924
# 식당 존재 x
# 진행상황 : 416/11924
# 식당 존재
# https://place.map.kakao.com/27578159
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 417/11924
# 식당 존재
# https://place.map.kakao.com/9832615
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 418/11924
# 식당 존재
# https://place.map.kakao.com/1207993040
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 419/11924
# 식당 존재 x
# 진행상황 : 420/11924
# 식당 존재
# https://place.map.kakao.com/14840168
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 421/11924
# 식당 존재
# https://place.map.kakao.com/16045290
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 422/11924
# 식당 존재
# https://place.map.kakao.com/1454139847
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 423/11924
# 식당 존재 x
# 진행상황 : 424/11924
# 식당 존재
# https://place.map.kakao.com/1758593953
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 425/11924
# 식당 존재 x
# 진행상황 : 426/11924
# 식당 존재
# https://place.map.kakao.com/45719180
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 427/11924
# 식당 존재
# https://place.map.kakao.com/16768747
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 428/11924
# 식당 존재
# https://place.map.kakao.com/808312408
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 429/11924
# 식당 존재 x
# 진행상황 : 430/11924
# 식당 존재 x
# 진행상황 : 431/11924
# 식당 존재
# https://place.map.kakao.com/21447475
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 432/11924
# 식당 존재 x
# 진행상황 : 433/11924
# 식당 존재
# https://place.map.kakao.com/664340865
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 434/11924
# 식당 존재
# https://place.map.kakao.com/20103280
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 435/11924
# 식당 존재
# https://place.map.kakao.com/8118241
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 436/11924
# 식당 존재 x
# 진행상황 : 437/11924
# 식당 존재
# https://place.map.kakao.com/1373315370
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 438/11924
# 식당 존재
# https://place.map.kakao.com/25531598
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 439/11924
# 식당 존재
# https://place.map.kakao.com/27281134
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 440/11924
# 식당 존재
# https://place.map.kakao.com/16095011
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 441/11924
# 식당 존재
# https://place.map.kakao.com/775445313
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 442/11924
# 식당 존재 x
# 진행상황 : 443/11924
# 식당 존재
# https://place.map.kakao.com/588185685
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 444/11924
# 식당 존재
# https://place.map.kakao.com/2034130515
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 445/11924
# 식당 존재
# https://place.map.kakao.com/1669153017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a363dfa393a7> in <module>
#      37         time.sleep(3)
#      38         html = driver.page_source
# ---> 39         time.sleep(20)
#      40         soup = BeautifulSoup(html, 'html.parser')
#      41         review_lists = soup.select('.list_evaluation > li')
#
# KeyboardInterrupt:

# %%
rating_df
# Out:
#        UserID         ItemID Rating    Timestamp
# 0     12p3llk       대림역 피자스쿨     5점  2021.02.26.
# 1      7ki33p       대림역 피자스쿨     5점  2019.07.27.
# 2                   대림역 피자스쿨     5점  2011.02.03.
# 3     19kn92r      중화역 미스터피자     5점  2020.07.04.
# 4     1950bi0      중화역 미스터피자     5점  2020.06.13.
# ...       ...            ...    ...          ...
# 1446     None  어린이대공원역 뉴욕떡볶이   None  2018.03.01.
# 1447     None  어린이대공원역 뉴욕떡볶이   None  2016.12.11.
# 1448           어린이대공원역 뉴욕떡볶이     5점  2017.03.24.
# 1449           어린이대공원역 뉴욕떡볶이     5점  2016.10.16.
# 1450           어린이대공원역 뉴욕떡볶이     5점  2016.06.28.
#
# [1451 rows x 4 columns]

# %%
img_elem
# Out:
#              ItemID img_url
# 0          대림역 피자스쿨    None
# 1          대림역 피자스쿨    None
# 2          대림역 피자스쿨    None
# 3         중화역 미스터피자    None
# 4         중화역 미스터피자    None
# ...             ...     ...
# 1446  어린이대공원역 뉴욕떡볶이      []
# 1447  어린이대공원역 뉴욕떡볶이    None
# 1448  어린이대공원역 뉴욕떡볶이    None
# 1449  어린이대공원역 뉴욕떡볶이    None
# 1450  어린이대공원역 뉴욕떡볶이    None
#
# [1451 rows x 2 columns]

# %%
data
# Out:
#                    상호명 상권업종중분류명     상권업종소분류명                  도로명주소  \
# 0                 이레식당       한식    한식/백반/한정식    서울특별시 동작구 성대로31길 71
# 1                 피자스쿨    패스트푸드         피자전문     서울특별시 영등포구 대림로 247
# 2                 장터국밥       한식      해장국/감자탕  서울특별시 도봉구 도봉로180나길 41
# 3      서울과학기술대학교제2학생식당    기타음식업  구내식당/자급식음식점      서울특별시 노원구 공릉로 232
# 4            초밥&참치전문점연   일식/수산물        참치전문점      서울특별시 광진구 능동로 179
# ...                ...      ...          ...                    ...
# 12182             벚꽃스시   일식/수산물     음식점-초밥전문    서울특별시 동작구 상도로30길 40
# 12183          생고기김치찌개       한식       갈비/삼겹살  서울특별시 구로구 개봉로11길 18-1
# 12184              피굽남       한식    한식/백반/한정식   서울특별시 중랑구 용마산로51길 45
# 12185            왕십리곱창       한식     곱창/양구이전문    서울특별시 중랑구 동일로163길 8
# 12186            기찻길풍경       한식     곱창/양구이전문    서울특별시 노원구 공릉로39길 21
#
#                     역명          거리                                카카오url  \
# 0             7호선 장승배기  252.070018  https://place.map.kakao.com/16821812
# 1         7호선 대림(구로구청)  655.825278  https://place.map.kakao.com/16300615
# 2              7호선 도봉산  490.786535                                  None
# 3      7호선 공릉(서울과학기술대)  651.158559                                  None
# 4      7호선 어린이대공원(세종대)   59.203796  https://place.map.kakao.com/21086077
# ...                ...         ...                                   ...
# 12182         7호선 장승배기  429.306668                                   NaN
# 12183        7호선 광명사거리  588.584222                                   NaN
# 12184          7호선 용마산  471.931015                                   NaN
# 12185           7호선 먹골  135.612799                                   NaN
# 12186         7호선 태릉입구  461.771739                                   NaN
#
#             역                  검색어
# 0        장승배기           장승배기역 이레식당
# 1          대림             대림역 피자스쿨
# 2         도봉산            도봉산역 장터국밥
# 3          공릉  공릉역 서울과학기술대학교제2학생식당
# 4      어린이대공원    어린이대공원역 초밥&참치전문점연
# ...       ...                  ...
# 12182    장승배기           장승배기역 벚꽃스시
# 12183   광명사거리       광명사거리역 생고기김치찌개
# 12184     용마산             용마산역 피굽남
# 12185      먹골            먹골역 왕십리곱창
# 12186    태릉입구          태릉입구역 기찻길풍경
#
# [12187 rows x 9 columns]

# %%
img_elem
# Out:
#              ItemID img_url
# 0          대림역 피자스쿨    None
# 1          대림역 피자스쿨    None
# 2          대림역 피자스쿨    None
# 3         중화역 미스터피자    None
# 4         중화역 미스터피자    None
# ...             ...     ...
# 1446  어린이대공원역 뉴욕떡볶이      []
# 1447  어린이대공원역 뉴욕떡볶이    None
# 1448  어린이대공원역 뉴욕떡볶이    None
# 1449  어린이대공원역 뉴욕떡볶이    None
# 1450  어린이대공원역 뉴욕떡볶이    None
#
# [1451 rows x 2 columns]

# %%
rating_df
# Out:
#        UserID         ItemID Rating    Timestamp
# 0     12p3llk       대림역 피자스쿨     5점  2021.02.26.
# 1      7ki33p       대림역 피자스쿨     5점  2019.07.27.
# 2                   대림역 피자스쿨     5점  2011.02.03.
# 3     19kn92r      중화역 미스터피자     5점  2020.07.04.
# 4     1950bi0      중화역 미스터피자     5점  2020.06.13.
# ...       ...            ...    ...          ...
# 1446     None  어린이대공원역 뉴욕떡볶이   None  2018.03.01.
# 1447     None  어린이대공원역 뉴욕떡볶이   None  2016.12.11.
# 1448           어린이대공원역 뉴욕떡볶이     5점  2017.03.24.
# 1449           어린이대공원역 뉴욕떡볶이     5점  2016.10.16.
# 1450           어린이대공원역 뉴욕떡볶이     5점  2016.06.28.
#
# [1451 rows x 4 columns]

# %%
review_elem
# Out:
#              ItemID                                             review
# 0          대림역 피자스쿨                                               최고예요
# 1          대림역 피자스쿨                                      깔끔하고 맛있고 친절하심
# 2          대림역 피자스쿨  테이크아웃 피자전문점! 정말 맛있어서 자주 이용하는 곳~ 저렴하고 친절해요 추천합니...
# 3         중화역 미스터피자  런치피자부페 갔다가 맛있는 피자 풍성하게 먹었어요. 사람도 많이 없고 한산해서 여유...
# 4         중화역 미스터피자  요즈음 코로나19도 있었고 6월 들어 날씨도 맘에 들지않고 등등 외부환경이 그리 녹...
# ...             ...                                                ...
# 1446  어린이대공원역 뉴욕떡볶이                                     근처에서  나름 소문난맛집
# 1447  어린이대공원역 뉴욕떡볶이                              근처에서 제일 맛있다  순대도 맛있음
# 1448  어린이대공원역 뉴욕떡볶이                     아드님인거 같은데 친절하네요 어머니는 뒷방으로 빠지세요
# 1449  어린이대공원역 뉴욕떡볶이                                            너무맛있어요
# 1450  어린이대공원역 뉴욕떡볶이                                             너무맛있어요
#
# [1451 rows x 2 columns]

# %%
img_elem.head()
# Out:
#       ItemID img_url
# 0   대림역 피자스쿨    None
# 1   대림역 피자스쿨    None
# 2   대림역 피자스쿨    None
# 3  중화역 미스터피자    None
# 4  중화역 미스터피자    None

# %%
ItemID_elem = rating_df['ItemID'].unique()

for k in range(len(ItemID_elem)) :
    User_ID_elem = rating_df.loc[rating_df['ItemID'] == ItemID_elem[k]]
    Uder_ID_elem = User_ID_elem[['UserID','ItemID']]
print(User_ID_elem)





ItemID_elem = img_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_img_elem = img_elem.loc[img_elem['ItemID'] == ItemID_elem[j]]
print(item_img_elem)



ItemID_elem = review_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_review_elem = review_elem.loc[review_elem['ItemID'] == ItemID_elem[j]]
print(item_review_elem)
# Out:
#        UserID         ItemID Rating    Timestamp
# 1434   v5ckg6  어린이대공원역 뉴욕떡볶이     5점  2021.04.11.
# 1435  1b6ki12  어린이대공원역 뉴욕떡볶이     5점  2021.03.19.
# 1436   bjpgo8  어린이대공원역 뉴욕떡볶이     3점  2021.01.19.
# 1437   8upmed  어린이대공원역 뉴욕떡볶이     1점  2020.11.01.
# 1438   e4mj58  어린이대공원역 뉴욕떡볶이     5점  2020.06.11.
# 1439   7kgh4f  어린이대공원역 뉴욕떡볶이     1점  2019.10.09.
# 1440   e5nqp1  어린이대공원역 뉴욕떡볶이     5점  2019.10.05.
# 1441   ua5ah9  어린이대공원역 뉴욕떡볶이     5점  2019.09.24.
# 1442   dotks6  어린이대공원역 뉴욕떡볶이     5점  2019.09.17.
# 1443   g4nrks  어린이대공원역 뉴욕떡볶이     5점  2019.09.01.
# 1444  109iik1  어린이대공원역 뉴욕떡볶이     5점  2019.06.20.
# 1445     None  어린이대공원역 뉴욕떡볶이   None  2018.12.14.
# 1446     None  어린이대공원역 뉴욕떡볶이   None  2018.03.01.
# 1447     None  어린이대공원역 뉴욕떡볶이   None  2016.12.11.
# 1448           어린이대공원역 뉴욕떡볶이     5점  2017.03.24.
# 1449           어린이대공원역 뉴욕떡볶이     5점  2016.10.16.
# 1450           어린이대공원역 뉴욕떡볶이     5점  2016.06.28.
#              ItemID img_url
# 1434  어린이대공원역 뉴욕떡볶이    None
# 1435  어린이대공원역 뉴욕떡볶이    None
# 1436  어린이대공원역 뉴욕떡볶이    None
# 1437  어린이대공원역 뉴욕떡볶이    None
# 1438  어린이대공원역 뉴욕떡볶이    None
# 1439  어린이대공원역 뉴욕떡볶이    None
# 1440  어린이대공원역 뉴욕떡볶이      []
# 1441  어린이대공원역 뉴욕떡볶이    None
# 1442  어린이대공원역 뉴욕떡볶이    None
# 1443  어린이대공원역 뉴욕떡볶이      []
# 1444  어린이대공원역 뉴욕떡볶이    None
# 1445  어린이대공원역 뉴욕떡볶이    None
# 1446  어린이대공원역 뉴욕떡볶이      []
# 1447  어린이대공원역 뉴욕떡볶이    None
# 1448  어린이대공원역 뉴욕떡볶이    None
# 1449  어린이대공원역 뉴욕떡볶이    None
# 1450  어린이대공원역 뉴욕떡볶이    None
#              ItemID                                             review
# 1434  어린이대공원역 뉴욕떡볶이                                  분식생각날때 자주 가는 땍뽁끼집
# 1435  어린이대공원역 뉴욕떡볶이  치즈폭탄김말이 바삭하고 존맛  카레떡볶이 약간 신전떡볶이 묽은 버전. 안 맵고 맛있...
# 1436  어린이대공원역 뉴욕떡볶이                                                좋아요
# 1437  어린이대공원역 뉴욕떡볶이                                       먹고나서 둘다 배탈.
# 1438  어린이대공원역 뉴욕떡볶이                        인생떡볶이.. 이 집은 진짜 뉴욕까지 진출해야한다
# 1439  어린이대공원역 뉴욕떡볶이                                           무뚝뚝, 불친절
# 1440  어린이대공원역 뉴욕떡볶이                                        맛 가격 양 최고예요
# 1441  어린이대공원역 뉴욕떡볶이         뉴욕느낌을 기대하고 갔다가 추억의 맛을 느끼고 나왔어요ㅎㅎ 떡볶이 맛있습니다
# 1442  어린이대공원역 뉴욕떡볶이                             진짜..먹고싶다....ㅠ 그리운 맛...
# 1443  어린이대공원역 뉴욕떡볶이  치즈 김말이 존맛탱! 저는 두명이서 갔는데 한상세트 + 치즈김말이 시켰어요 너무 양...
# 1444  어린이대공원역 뉴욕떡볶이  후기보고 집앞이라 찾아가서 포장했었는데 진짜 존맛탱입니다. 치즈폭탄김말이인가 그것도...
# 1445  어린이대공원역 뉴욕떡볶이                                                좋아요
# 1446  어린이대공원역 뉴욕떡볶이                                     근처에서  나름 소문난맛집
# 1447  어린이대공원역 뉴욕떡볶이                              근처에서 제일 맛있다  순대도 맛있음
# 1448  어린이대공원역 뉴욕떡볶이                     아드님인거 같은데 친절하네요 어머니는 뒷방으로 빠지세요
# 1449  어린이대공원역 뉴욕떡볶이                                            너무맛있어요
# 1450  어린이대공원역 뉴욕떡볶이                                             너무맛있어요

# %%
rating_df.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_rating(263).csv')

# %%
User_ID_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_User_ID(263).csv')
item_img_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_img(263).csv')
item_review_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_review(263).csv')

# %%
ItemID_elem = rating_df['ItemID'].unique()
len(ItemID_elem)
# Out:
# 99

# %%
data.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_(1)263url.csv')
