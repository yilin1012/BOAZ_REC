# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/Final Res.csv')
df
# Out:
#           상가업소번호        상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0       17163092  도전최강달인왕만두    NaN         Q       음식       Q01       한식
# 1       17120456         이때    NaN         Q       음식       Q01       한식
# 2       17175350      L.A.D    NaN         Q       음식       Q01       한식
# 3       17175311    제이씨에스푸드    NaN         Q       음식       Q01       한식
# 4       17174175        비지트    NaN         Q       음식       Q01       한식
# ...          ...        ...    ...       ...      ...       ...      ...
# 135805  17218896       얼음과자    NaN         Q       음식       Q07    패스트푸드
# 135806  17218871      오이소서울    상일점         Q       음식       Q07    패스트푸드
# 135807  17218873   얼음왕국명일14    6호점         Q       음식       Q07    패스트푸드
# 135808  17218875       얼음과자    NaN         Q       음식       Q07    패스트푸드
# 135809  17216456       꽁꽁냠냠  서울1호점         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                 도로명주소   구우편번호  \
# ...

# %%
df['카카오url'] = None

# %%
df[50:90]
# Out:
#       상가업소번호           상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 50  20685006       의정부부대찌개     NaN         Q       음식       Q01       한식
# 51  27373876         전주영양탕     NaN         Q       음식       Q05   닭/오리요리
# 52  20604340        손가네빈대떡     NaN         Q       음식       Q01       한식
# 53  15567127           아이포     NaN         Q       음식       Q10  별식/퓨전요리
# 54  23408930           분노지     NaN         Q       음식       Q03   일식/수산물
# 55  26660089            공간     NaN         Q       음식       Q06       양식
# 56  20573592         부킹메들리     NaN         Q       음식       Q09     유흥주점
# 57  28482564       인생극장쪽갈비     NaN         Q       음식       Q01       한식
# 58  23667164            대송     NaN         Q       음식       Q03   일식/수산물
# 59  25934755           봉쥬르     NaN         Q       음식       Q02       중식
# 60  28490990      406번째스토브     NaN         Q       음식       Q12   커피점/카페
# 61  22791439         로얄커피숍     NaN         Q       음식       Q12   커피점/카페
# ...

# %%
line5 = df[df['역명'].str.contains('5호선')] ## df[조건식]
line5
# Out:
#           상가업소번호        상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0       17163092  도전최강달인왕만두   NaN         Q       음식       Q01       한식
# 12      28480888      옥돌영양탕   NaN         Q       음식       Q05   닭/오리요리
# 14      17175285       은진이네   NaN         Q       음식       Q01       한식
# 15      17175333       흥부보쌈   NaN         Q       음식       Q01       한식
# 28      20665661      가파도참치   NaN         Q       음식       Q03   일식/수산물
# ...          ...        ...   ...       ...      ...       ...      ...
# 135800  17212093       만랩커피  오금역점         Q       음식       Q12   커피점/카페
# 135805  17218896       얼음과자   NaN         Q       음식       Q07    패스트푸드
# 135806  17218871      오이소서울   상일점         Q       음식       Q07    패스트푸드
# 135807  17218873   얼음왕국명일14   6호점         Q       음식       Q07    패스트푸드
# 135808  17218875       얼음과자   NaN         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...   구우편번호   신우편번호  동정보  층정보  호정보  \
# ...

# %%
line5.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line5.csv')

# %%
line7 = df[df['역명'].str.contains('7호선')] ## df[조건식]
line7
# Out:
#           상가업소번호              상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 36      20033652             이레식당   NaN         Q       음식       Q01       한식
# 69      20480264             피자스쿨   NaN         Q       음식       Q07    패스트푸드
# 84      10033391             장터국밥   NaN         Q       음식       Q01       한식
# 97      20819907  서울과학기술대학교제2학생식당   NaN         Q       음식       Q14    기타음식업
# 98      20821938        초밥&참치전문점연   NaN         Q       음식       Q03   일식/수산물
# ...          ...              ...   ...       ...      ...       ...      ...
# 135732  17208733             벚꽃스시   NaN         Q       음식       Q03   일식/수산물
# 135741  17228573          생고기김치찌개   NaN         Q       음식       Q01       한식
# 135758  17212010              피굽남  사가정점         Q       음식       Q01       한식
# 135779  17251264            왕십리곱창   NaN         Q       음식       Q01       한식
# 135793  17228636            기찻길풍경   NaN         Q       음식       Q01       한식
#
# ...

# %%
line7.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7.csv')

# %%
line8 = df[df['역명'].str.contains('8호선')] ## df[조건식]
line8
# Out:
#           상가업소번호           상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 13      17175289       양푼이김치찌개     NaN         Q       음식       Q01       한식
# 16      17174967         고수의족발     NaN         Q       음식       Q01       한식
# 57      28482564       인생극장쪽갈비     NaN         Q       음식       Q01       한식
# 61      22791439         로얄커피숍     NaN         Q       음식       Q12   커피점/카페
# 70      23430253           부탄츄  롯데월드몰점         Q       음식       Q01       한식
# ...          ...           ...     ...       ...      ...       ...      ...
# 135644  17240637  오태식해바라기치킨&푸드     NaN         Q       음식       Q09     유흥주점
# 135649  17209656         왕십리막창     NaN         Q       음식       Q01       한식
# 135703  17213004        세라젬웰카페     문정점         Q       음식       Q12   커피점/카페
# 135735  17208380         가락정초밥     NaN         Q       음식       Q03   일식/수산물
# 135755  17216629          룸서비스     NaN         Q       음식       Q13  음식배달서비스
#
# ...

# %%
line8.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line8.csv')

# %%
line9 = df[df['역명'].str.contains('9호선')] ## df[조건식]
line9
# Out:
#           상가업소번호       상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 7       17174062     호구의주방    NaN         Q       음식       Q01       한식
# 11      20536992     이삭토스트    NaN         Q       음식       Q07    패스트푸드
# 17      17174636  호랑이가만든족발    NaN         Q       음식       Q01       한식
# 38      23263504      열라닭발    NaN         Q       음식       Q05   닭/오리요리
# 51      27373876     전주영양탕    NaN         Q       음식       Q05   닭/오리요리
# ...          ...       ...    ...       ...      ...       ...      ...
# 135787  17207559      단골손님  강서구청점         Q       음식       Q09     유흥주점
# 135795  17218860       롤러와    NaN         Q       음식       Q04       분식
# 135799  17212141      카페시모    NaN         Q       음식       Q12   커피점/카페
# 135803  17212604  개성순대1967    학동점         Q       음식       Q01       한식
# 135804  17216469      더달달가   양성지점         Q       음식       Q07    패스트푸드
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...   구우편번호   신우편번호  동정보  층정보  호정보  \
# ...

# %%
line9.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line9.csv')

# %%
lineUi = df[df['역명'].str.contains('우이신설')] ## df[조건식]
lineUi
# Out:
#           상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 22      15499579      굽자나치킨호프  NaN         Q       음식       Q09     유흥주점
# 44      15640324  봉구비어삼양동사거리점  NaN         Q       음식       Q09     유흥주점
# 65      23312390           미뇽  NaN         Q       음식       Q09     유흥주점
# 75      20587293        친구네분식  NaN         Q       음식       Q04       분식
# 112     23195736         퓨처핸접  NaN         Q       음식       Q01       한식
# ...          ...          ...  ...       ...      ...       ...      ...
# 135554  17273368       진.회.초밥  NaN         Q       음식       Q03   일식/수산물
# 135568  17228711         인생보쌈  NaN         Q       음식       Q01       한식
# 135577  17270341      키토산우이산장  NaN         Q       음식       Q01       한식
# 135651  17211522     어허라곱창&호프  NaN         Q       음식       Q01       한식
# 135710  17218829        삼대고깃간  NaN         Q       음식       Q01       한식
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...   구우편번호   신우편번호  동정보  층정보  호정보  \
# ...

# %%
lineUi.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineUi.csv')

# %%
lineSuin = df[df['역명'].str.contains('분당')] ## df[조건식]
lineSuin
# Out:
#           상가업소번호      상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 63      20484278     유미분식    NaN         Q       음식       Q04       분식
# 89      25555021     바른치킨  강남선릉점         Q       음식       Q05   닭/오리요리
# 122     20012563  미고스타수퍼점    NaN         Q       음식       Q08  제과제빵떡케익
# 182     25472959    노란고무줄    NaN         Q       음식       Q12   커피점/카페
# 186     20028468        호    NaN         Q       음식       Q09     유흥주점
# ...          ...      ...    ...       ...      ...       ...      ...
# 135611  17207394   비스트로성수    NaN         Q       음식       Q06       양식
# 135613  17271614   마이클돈까스   압구정점         Q       음식       Q06       양식
# 135617  17229145  두마리찜닭두찜  강남개포점         Q       음식       Q05   닭/오리요리
# 135700  17229191      유오리    NaN         Q       음식       Q05   닭/오리요리
# 135734  17211479    스시산코우    NaN         Q       음식       Q03   일식/수산물
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...   구우편번호   신우편번호  동정보  층정보     호정보  \
# ...

# %%
lineSuin.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin.csv')

# %%
line6 = df[df['역명'].str.contains('6')] ## df[조건식]
line6
# Out:
# Empty DataFrame
# Columns: [상가업소번호, 상호명, 지점명, 상권업종대분류코드, 상권업종대분류명, 상권업종중분류코드, 상권업종중분류명, 상권업종소분류코드, 상권업종소분류명, 표준산업분류코드, 표준산업분류명, 시도코드, 시도명, 시군구코드, 시군구명, 행정동코드, 행정동명, 법정동코드, 법정동명, 지번코드, 대지구분코드, 대지구분명, 지번본번지, 지번부번지, 지번주소, 도로명코드, 도로명, 건물본번지, 건물부번지, 건물관리번호, 건물명, 도로명주소, 구우편번호, 신우편번호, 동정보, 층정보, 호정보, 경도, 위도, 역명, 거리, 카카오url]
# Index: []
#
# [0 rows x 42 columns]
