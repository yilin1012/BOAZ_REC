# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from selenium.webdriver.common.keys import Keys
import pandas as pd
import math
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import json

# %%
data = pd.read_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7.csv')
data
# 카페 데이터만
data = data.loc[data['상권업종중분류명'] == '커피점/카페']  
data
# Out:
#        Unnamed: 0    상가업소번호         상호명       지점명 상권업종대분류코드 상권업종대분류명  \
# 24            270  20297127       카페오작교       NaN         Q       음식
# 25            282  23238698        들꽃누리       NaN         Q       음식
# 34            469  20017448         커피빈  코리아청담에스점         Q       음식
# 37            497  24327928  건대포토카페프린세스       NaN         Q       음식
# 47            586  20023467         커피빈  코리아청담성당점         Q       음식
# ...           ...       ...         ...       ...       ...      ...
# 12149      135223  17254892    안다미로팬케이크       NaN         Q       음식
# 12150      135226  17252483        초코라떼      건대역점         Q       음식
# 12152      135251  17207986          카페     동네항동점         Q       음식
# 12159      135345  17243108     코끼리키즈까페       NaN         Q       음식
# 12170      135522  17249835      ON&OFF       NaN         Q       음식
#
#       상권업종중분류코드 상권업종중분류명 상권업종소분류코드     상권업종소분류명  ...   구우편번호   신우편번호  동정보  \
# 24          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135953  6070.0  NaN
# 25          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  150070  7412.0  NaN
# 34          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135955  6011.0  NaN
# 37          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143190  5073.0  NaN
# 47          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135953  6074.0  NaN
# ...         ...      ...       ...          ...  ...     ...     ...  ...
# 12149       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143915  5012.0  NaN
# 12150       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143854  5066.0  NaN
# 12152       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  152140  8362.0  NaN
# 12159       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  152815  8352.0  NaN
# 12170       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135814  6044.0  NaN
#
#        층정보  호정보          경도         위도               역명          거리 카카오url
# 24       1  NaN  127.049293  37.522951           7호선 청담  398.760647    NaN
# 25       1  NaN  126.898633  37.497079     7호선 대림(구로구청)  368.888504    NaN
# 34       1  109  127.047216  37.525250           7호선 청담  675.120538    NaN
# 37       1  NaN  127.068745  37.539802         7호선 건대입구   60.940672    NaN
# 47       2  NaN  127.050021  37.519902           7호선 청담  229.848907    NaN
# ...    ...  ...         ...        ...              ...         ...    ...
# 12149  NaN  NaN  127.071012  37.544992  7호선 어린이대공원(세종대)  355.054760    NaN
# 12150    7  NaN  127.074625  37.538335  7호선 어린이대공원(세종대)  592.981894    NaN
# 12152    1  NaN  126.821130  37.482852   7호선 온수(성공회대입구)  567.166627    NaN
# 12159    2  NaN  126.854261  37.486412        7호선 광명사거리  478.139096    NaN
# 12170    6  NaN  127.021176  37.512863           7호선 학동  125.163948    NaN
#
# [1879 rows x 43 columns]

# %%
data = data[["상호명","상권업종중분류명","상권업종소분류명","도로명주소","역명","거리","카카오url"]]
data["역"] = data["역명"].apply(lambda x : x.split(" ")[1])
data["역"] = data["역"].apply(lambda x : x.split("(")[0])
data["검색어"] = data.apply(lambda x : x["역"] + "역 " + str(x["상호명"]),axis=1)
data
# Out:
#               상호명 상권업종중분류명     상권업종소분류명                 도로명주소  \
# 24          카페오작교   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로92길 26
# 25           들꽃누리   커피점/카페  커피전문점/카페/다방    서울특별시 영등포구 대림로 183
# 34            커피빈   커피점/카페  커피전문점/카페/다방    서울특별시 강남구 압구정로 461
# 37     건대포토카페프린세스   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 동일로20길 98
# 47            커피빈   커피점/카페  커피전문점/카페/다방     서울특별시 강남구 삼성로 716
# ...           ...      ...          ...                   ...
# 12149    안다미로팬케이크   커피점/카페  커피전문점/카페/다방      서울특별시 광진구 군자로 19
# 12150        초코라떼   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 아차산로36길 5
# 12152          카페   커피점/카페  커피전문점/카페/다방   서울특별시 구로구 연동로11길 19
# 12159     코끼리키즈까페   커피점/카페  커피전문점/카페/다방    서울특별시 구로구 개봉로3길 36
# 12170      ON&OFF   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 강남대로136길 6
#
#                     역명          거리  카카오url       역               검색어
# 24              7호선 청담  398.760647     NaN      청담         청담역 카페오작교
# 25        7호선 대림(구로구청)  368.888504     NaN      대림          대림역 들꽃누리
# 34              7호선 청담  675.120538     NaN      청담           청담역 커피빈
# 37            7호선 건대입구   60.940672     NaN    건대입구  건대입구역 건대포토카페프린세스
# 47              7호선 청담  229.848907     NaN      청담           청담역 커피빈
# ...                ...         ...     ...     ...               ...
# 12149  7호선 어린이대공원(세종대)  355.054760     NaN  어린이대공원  어린이대공원역 안다미로팬케이크
# 12150  7호선 어린이대공원(세종대)  592.981894     NaN  어린이대공원      어린이대공원역 초코라떼
# 12152   7호선 온수(성공회대입구)  567.166627     NaN      온수            온수역 카페
# 12159        7호선 광명사거리  478.139096     NaN   광명사거리    광명사거리역 코끼리키즈까페
# 12170           7호선 학동  125.163948     NaN      학동        학동역 ON&OFF
#
# [1879 rows x 9 columns]

# %%
items = data["검색어"][:196]
items
# Out:
# 24             청담역 카페오작교
# 25              대림역 들꽃누리
# 34               청담역 커피빈
# 37      건대입구역 건대포토카페프린세스
# 47               청담역 커피빈
#               ...
# 1404             사가정역 카페
# 1405             사가정역 카페
# 1422      총신대입구역 신묘한사주타로
# 1428         어린이대공원역 엔조이
# 1432         뚝섬유원지역 쥬씨차얌
# Name: 검색어, Length: 196, dtype: object

# %%
rating_df = pd.DataFrame(columns = ["UserID","ItemID","Rating","Timestamp"])
img_elem = pd.DataFrame(columns = ["ItemID","img_url"])
review_elem = pd.DataFrame(columns = ["ItemID", "review"])
user_review_id = {}
review_json = {}
image_json = {}

# %%
# 드라이버 구동
driver = webdriver.Chrome(executable_path='C:/Users/정예림/Desktop/추천시스템 프로젝트/chromedriver.exe')
# 창 크기 최대화
driver.maximize_window() 



count = 0
current = 0
indexing = 0
goal = len(items)
for item in items :
    current += 1
    print('진행상황 : ', current,'/',goal,sep="")
    # 리뷰가 없을 때의 코드
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    time.sleep(2)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        time.sleep(2)
        content_url = reviewbutton.get_attribute("href") 
        #상세보기 URL수집
        url = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').get_attribute('href')
        data.iloc[indexing,-3] = url
        print(url)
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        time.sleep(20)
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                try:
                    row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_ur}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)

                    time.sleep(1)
                except:
                    row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_url}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    time.sleep(1)

                
                    
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,500):
                time.sleep(3)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        try:
                            row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                            
                        except:
                            row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                        
                        
                            
        except:
            print("더 이상 리뷰 존재 X")
            driver.close()
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        data.iloc[indexing,-3] = None
        print("식당 존재 x")
    
    indexing += 1
# Out:
# 진행상황 : 1/196
# 식당 존재 x
# 진행상황 : 2/196
# 식당 존재 x
# 진행상황 : 3/196
# 식당 존재
# https://place.map.kakao.com/8103501
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 4/196
# 식당 존재 x
# 진행상황 : 5/196
# 식당 존재
# https://place.map.kakao.com/8103501
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 6/196
# 식당 존재
# https://place.map.kakao.com/10060027
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 7/196
# 식당 존재 x
# 진행상황 : 8/196
# 식당 존재 x
# 진행상황 : 9/196
# 식당 존재
# https://place.map.kakao.com/746969844
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 10/196
# 식당 존재
# https://place.map.kakao.com/1691675030
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 11/196
# 식당 존재
# https://place.map.kakao.com/24637865
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 12/196
# 식당 존재 x
# 진행상황 : 13/196
# 식당 존재 x
# 진행상황 : 14/196
# 식당 존재
# https://place.map.kakao.com/26561658
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 15/196
# 식당 존재 x
# 진행상황 : 16/196
# 식당 존재
# https://place.map.kakao.com/23556852
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 17/196
# 식당 존재
# https://place.map.kakao.com/1003027186
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 18/196
# 식당 존재
# https://place.map.kakao.com/18521870
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 19/196
# 식당 존재 x
# 진행상황 : 20/196
# 식당 존재
# https://place.map.kakao.com/1609773264
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 21/196
# 식당 존재
# https://place.map.kakao.com/1969655656
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 22/196
# 식당 존재
# https://place.map.kakao.com/26993662
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 23/196
# 식당 존재
# https://place.map.kakao.com/1772084332
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 24/196
# 식당 존재
# https://place.map.kakao.com/21424661
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 25/196
# 식당 존재
# https://place.map.kakao.com/1618551124
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 26/196
# 식당 존재
# https://place.map.kakao.com/21413793
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 27/196
# 식당 존재
# https://place.map.kakao.com/19574605
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 28/196
# 식당 존재
# https://place.map.kakao.com/12373669
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 29/196
# 식당 존재
# https://place.map.kakao.com/21194552
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 30/196
# 식당 존재 x
# 진행상황 : 31/196
# 식당 존재
# https://place.map.kakao.com/17127063
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 32/196
# 식당 존재 x
# 진행상황 : 33/196
# 식당 존재
# https://place.map.kakao.com/1751847609
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 34/196
# 식당 존재 x
# 진행상황 : 35/196
# 식당 존재
# https://place.map.kakao.com/2035438739
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 36/196
# 식당 존재 x
# 진행상황 : 37/196
# 식당 존재 x
# 진행상황 : 38/196
# 식당 존재
# https://place.map.kakao.com/21527115
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 39/196
# 식당 존재 x
# 진행상황 : 40/196
# 식당 존재
# https://place.map.kakao.com/812839131
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 41/196
# 식당 존재 x
# 진행상황 : 42/196
# 식당 존재 x
# 진행상황 : 43/196
# 식당 존재
# https://place.map.kakao.com/24812697
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 44/196
# 식당 존재
# https://place.map.kakao.com/2025356371
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 45/196
# 식당 존재
# https://place.map.kakao.com/16588905
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 46/196
# 식당 존재
# https://place.map.kakao.com/995402415
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 47/196
# 식당 존재 x
# 진행상황 : 48/196
# 식당 존재 x
# 진행상황 : 49/196
# 식당 존재
# https://place.map.kakao.com/17127063
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 50/196
# 식당 존재 x
# 진행상황 : 51/196
# 식당 존재 x
# 진행상황 : 52/196
# 식당 존재 x
# 진행상황 : 53/196
# 식당 존재
# https://place.map.kakao.com/1317042972
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 54/196
# 식당 존재
# https://place.map.kakao.com/8143357
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 55/196
# 식당 존재 x
# 진행상황 : 56/196
# 식당 존재 x
# 진행상황 : 57/196
# 식당 존재 x
# 진행상황 : 58/196
# 식당 존재 x
# 진행상황 : 59/196
# 식당 존재
# https://place.map.kakao.com/508797207
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 60/196
# 식당 존재
# https://place.map.kakao.com/1605351373
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 61/196
# 식당 존재 x
# 진행상황 : 62/196
# 식당 존재 x
# 진행상황 : 63/196
# 식당 존재
# https://place.map.kakao.com/517418173
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 64/196
# 식당 존재
# https://place.map.kakao.com/362201941
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 65/196
# 식당 존재
# https://place.map.kakao.com/1521767127
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 66/196
# 식당 존재 x
# 진행상황 : 67/196
# 식당 존재 x
# 진행상황 : 68/196
# 식당 존재 x
# 진행상황 : 69/196
# 식당 존재
# https://place.map.kakao.com/24975782
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 70/196
# 식당 존재 x
# 진행상황 : 71/196
# 식당 존재
# https://place.map.kakao.com/12508558
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 72/196
# 식당 존재 x
# 진행상황 : 73/196
# 식당 존재
# https://place.map.kakao.com/864254714
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 74/196
# 식당 존재 x
# 진행상황 : 75/196
# 식당 존재 x
# 진행상황 : 76/196
# 식당 존재 x
# 진행상황 : 77/196
# 식당 존재
# https://place.map.kakao.com/12118840
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 78/196
# 식당 존재 x
# 진행상황 : 79/196
# 식당 존재
# https://place.map.kakao.com/1194487940
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 80/196
# 식당 존재
# https://place.map.kakao.com/1482453353
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 81/196
# 식당 존재
# https://place.map.kakao.com/1846905391
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 82/196
# 식당 존재
# https://place.map.kakao.com/25693014
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 83/196
# 식당 존재
# https://place.map.kakao.com/26889467
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 84/196
# 식당 존재
# https://place.map.kakao.com/1466108122
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 85/196
# 식당 존재
# https://place.map.kakao.com/27360568
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 86/196
# 식당 존재 x
# 진행상황 : 87/196
# 식당 존재
# https://place.map.kakao.com/27501503
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 88/196
# 식당 존재
# https://place.map.kakao.com/27578159
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 89/196
# 식당 존재
# https://place.map.kakao.com/1207993040
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 90/196
# 식당 존재
# https://place.map.kakao.com/14840168
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 91/196
# 식당 존재
# https://place.map.kakao.com/16768747
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 92/196
# 식당 존재 x
# 진행상황 : 93/196
# 식당 존재
# https://place.map.kakao.com/25575750
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 94/196
# 식당 존재
# https://place.map.kakao.com/1975284767
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 95/196
# 식당 존재
# https://place.map.kakao.com/733179174
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 96/196
# 식당 존재
# https://place.map.kakao.com/20613466
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 97/196
# 식당 존재
# https://place.map.kakao.com/16501586
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 98/196
# 식당 존재
# https://place.map.kakao.com/27179440
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 99/196
# 식당 존재
# https://place.map.kakao.com/1344224352
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 100/196
# 식당 존재 x
# 진행상황 : 101/196
# 식당 존재
# https://place.map.kakao.com/1461555681
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 102/196
# 식당 존재 x
# 진행상황 : 103/196
# 식당 존재 x
# 진행상황 : 104/196
# 식당 존재
# https://place.map.kakao.com/10538394
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 105/196
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-a363dfa393a7> in <module>
#      14     print('진행상황 : ', current,'/',goal,sep="")
#      15     # 리뷰가 없을 때의 코드
# ---> 16     driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
#      17     searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
#      18     searchbox.send_keys(item)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=90.0.4430.212)

# %%
rating_df
# Out:
#       UserID           ItemID Rating    Timestamp
# 0    151kktb          청담역 커피빈     5점  2021.04.02.
# 1       None          청담역 커피빈   None  2013.12.25.
# 2                     청담역 커피빈     5점  2016.06.09.
# 3    151kktb          청담역 커피빈     5점  2021.04.02.
# 4       None          청담역 커피빈   None  2013.12.25.
# ..       ...              ...    ...          ...
# 231   fucpf8  숭실대입구역 스타벅스숭실대점     4점  2021.04.24.
# 232   n0qfcg  숭실대입구역 스타벅스숭실대점     3점  2021.03.16.
# 233   sa540j  숭실대입구역 스타벅스숭실대점     2점  2020.07.23.
# 234   gfvo2o  숭실대입구역 스타벅스숭실대점     1점  2020.06.28.
# 235  1366or8  숭실대입구역 스타벅스숭실대점     5점  2020.01.01.
#
# [236 rows x 4 columns]

# %%
img_elem
# Out:
#               ItemID img_url
# 0            청담역 커피빈    None
# 1            청담역 커피빈      []
# 2            청담역 커피빈    None
# 3            청담역 커피빈    None
# 4            청담역 커피빈      []
# ..               ...     ...
# 231  숭실대입구역 스타벅스숭실대점    None
# 232  숭실대입구역 스타벅스숭실대점    None
# 233  숭실대입구역 스타벅스숭실대점    None
# 234  숭실대입구역 스타벅스숭실대점    None
# 235  숭실대입구역 스타벅스숭실대점    None
#
# [236 rows x 2 columns]

# %%
data
# Out:
#               상호명 상권업종중분류명     상권업종소분류명                 도로명주소  \
# 24          카페오작교   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로92길 26
# 25           들꽃누리   커피점/카페  커피전문점/카페/다방    서울특별시 영등포구 대림로 183
# 34            커피빈   커피점/카페  커피전문점/카페/다방    서울특별시 강남구 압구정로 461
# 37     건대포토카페프린세스   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 동일로20길 98
# 47            커피빈   커피점/카페  커피전문점/카페/다방     서울특별시 강남구 삼성로 716
# ...           ...      ...          ...                   ...
# 12149    안다미로팬케이크   커피점/카페  커피전문점/카페/다방      서울특별시 광진구 군자로 19
# 12150        초코라떼   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 아차산로36길 5
# 12152          카페   커피점/카페  커피전문점/카페/다방   서울특별시 구로구 연동로11길 19
# 12159     코끼리키즈까페   커피점/카페  커피전문점/카페/다방    서울특별시 구로구 개봉로3길 36
# 12170      ON&OFF   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 강남대로136길 6
#
#                     역명          거리                               카카오url  \
# 24              7호선 청담  398.760647                                  NaN
# 25        7호선 대림(구로구청)  368.888504                                  NaN
# 34              7호선 청담  675.120538  https://place.map.kakao.com/8103501
# 37            7호선 건대입구   60.940672                                 None
# 47              7호선 청담  229.848907  https://place.map.kakao.com/8103501
# ...                ...         ...                                  ...
# 12149  7호선 어린이대공원(세종대)  355.054760                                  NaN
# 12150  7호선 어린이대공원(세종대)  592.981894                                  NaN
# 12152   7호선 온수(성공회대입구)  567.166627                                  NaN
# 12159        7호선 광명사거리  478.139096                                  NaN
# 12170           7호선 학동  125.163948                                  NaN
#
#             역               검색어
# 24         청담         청담역 카페오작교
# 25         대림          대림역 들꽃누리
# 34         청담           청담역 커피빈
# 37       건대입구  건대입구역 건대포토카페프린세스
# 47         청담           청담역 커피빈
# ...       ...               ...
# 12149  어린이대공원  어린이대공원역 안다미로팬케이크
# 12150  어린이대공원      어린이대공원역 초코라떼
# 12152      온수            온수역 카페
# 12159   광명사거리    광명사거리역 코끼리키즈까페
# 12170      학동        학동역 ON&OFF
#
# [1879 rows x 9 columns]

# %%
img_elem
# Out:
#               ItemID img_url
# 0            청담역 커피빈    None
# 1            청담역 커피빈      []
# 2            청담역 커피빈    None
# 3            청담역 커피빈    None
# 4            청담역 커피빈      []
# ..               ...     ...
# 231  숭실대입구역 스타벅스숭실대점    None
# 232  숭실대입구역 스타벅스숭실대점    None
# 233  숭실대입구역 스타벅스숭실대점    None
# 234  숭실대입구역 스타벅스숭실대점    None
# 235  숭실대입구역 스타벅스숭실대점    None
#
# [236 rows x 2 columns]

# %%
rating_df
# Out:
#       UserID           ItemID Rating    Timestamp
# 0    151kktb          청담역 커피빈     5점  2021.04.02.
# 1       None          청담역 커피빈   None  2013.12.25.
# 2                     청담역 커피빈     5점  2016.06.09.
# 3    151kktb          청담역 커피빈     5점  2021.04.02.
# 4       None          청담역 커피빈   None  2013.12.25.
# ..       ...              ...    ...          ...
# 231   fucpf8  숭실대입구역 스타벅스숭실대점     4점  2021.04.24.
# 232   n0qfcg  숭실대입구역 스타벅스숭실대점     3점  2021.03.16.
# 233   sa540j  숭실대입구역 스타벅스숭실대점     2점  2020.07.23.
# 234   gfvo2o  숭실대입구역 스타벅스숭실대점     1점  2020.06.28.
# 235  1366or8  숭실대입구역 스타벅스숭실대점     5점  2020.01.01.
#
# [236 rows x 4 columns]

# %%
review_elem
# Out:
#               ItemID                                             review
# 0            청담역 커피빈                                               최고예요
# 1            청담역 커피빈                                           성당 앞 커피빈
# 2            청담역 커피빈  여기 매니저 매우매우매우 친절하다. 최고의 티타임을 가지기에 좋은 매장이다. 그리고...
# 3            청담역 커피빈                                               최고예요
# 4            청담역 커피빈                                           성당 앞 커피빈
# ..               ...                                                ...
# 231  숭실대입구역 스타벅스숭실대점                                                좋아요
# 232  숭실대입구역 스타벅스숭실대점                                              보통이에요
# 233  숭실대입구역 스타벅스숭실대점  블론드 서머 라떼 2일 전에 먹었는데 크림이 다 녹은 건지 어떻게 된 건지 펑퍼짐하...
# 234  숭실대입구역 스타벅스숭실대점                           주말 카운터 알바 완전 별로. 아는게 없는듯
# 235  숭실대입구역 스타벅스숭실대점  작년에.....있었던 일입니다....  텀블러 안에 미리 넣어 두었던 보이차 가루를...
#
# [236 rows x 2 columns]

# %%
img_elem.head()
# Out:
#     ItemID img_url
# 0  청담역 커피빈    None
# 1  청담역 커피빈      []
# 2  청담역 커피빈    None
# 3  청담역 커피빈    None
# 4  청담역 커피빈      []

# %%
ItemID_elem = rating_df['ItemID'].unique()

for k in range(len(ItemID_elem)) :
    User_ID_elem = rating_df.loc[rating_df['ItemID'] == ItemID_elem[k]]
    Uder_ID_elem = User_ID_elem[['UserID','ItemID']]
print(User_ID_elem)





ItemID_elem = img_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_img_elem = img_elem.loc[img_elem['ItemID'] == ItemID_elem[j]]
print(item_img_elem)



ItemID_elem = review_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_review_elem = review_elem.loc[review_elem['ItemID'] == ItemID_elem[j]]
print(item_review_elem)
# Out:
#       UserID           ItemID Rating    Timestamp
# 221   fucpf8  숭실대입구역 스타벅스숭실대점     4점  2021.04.24.
# 222   n0qfcg  숭실대입구역 스타벅스숭실대점     3점  2021.03.16.
# 223   sa540j  숭실대입구역 스타벅스숭실대점     2점  2020.07.23.
# 224   gfvo2o  숭실대입구역 스타벅스숭실대점     1점  2020.06.28.
# 225  1366or8  숭실대입구역 스타벅스숭실대점     5점  2020.01.01.
# 226   fucpf8  숭실대입구역 스타벅스숭실대점     4점  2021.04.24.
# 227   n0qfcg  숭실대입구역 스타벅스숭실대점     3점  2021.03.16.
# 228   sa540j  숭실대입구역 스타벅스숭실대점     2점  2020.07.23.
# 229   gfvo2o  숭실대입구역 스타벅스숭실대점     1점  2020.06.28.
# 230  1366or8  숭실대입구역 스타벅스숭실대점     5점  2020.01.01.
# 231   fucpf8  숭실대입구역 스타벅스숭실대점     4점  2021.04.24.
# 232   n0qfcg  숭실대입구역 스타벅스숭실대점     3점  2021.03.16.
# 233   sa540j  숭실대입구역 스타벅스숭실대점     2점  2020.07.23.
# 234   gfvo2o  숭실대입구역 스타벅스숭실대점     1점  2020.06.28.
# 235  1366or8  숭실대입구역 스타벅스숭실대점     5점  2020.01.01.
#               ItemID img_url
# 221  숭실대입구역 스타벅스숭실대점    None
# 222  숭실대입구역 스타벅스숭실대점    None
# 223  숭실대입구역 스타벅스숭실대점    None
# 224  숭실대입구역 스타벅스숭실대점    None
# 225  숭실대입구역 스타벅스숭실대점    None
# 226  숭실대입구역 스타벅스숭실대점    None
# 227  숭실대입구역 스타벅스숭실대점    None
# 228  숭실대입구역 스타벅스숭실대점    None
# 229  숭실대입구역 스타벅스숭실대점    None
# 230  숭실대입구역 스타벅스숭실대점    None
# 231  숭실대입구역 스타벅스숭실대점    None
# 232  숭실대입구역 스타벅스숭실대점    None
# 233  숭실대입구역 스타벅스숭실대점    None
# 234  숭실대입구역 스타벅스숭실대점    None
# 235  숭실대입구역 스타벅스숭실대점    None
#               ItemID                                             review
# 221  숭실대입구역 스타벅스숭실대점                                                좋아요
# 222  숭실대입구역 스타벅스숭실대점                                              보통이에요
# 223  숭실대입구역 스타벅스숭실대점  블론드 서머 라떼 2일 전에 먹었는데 크림이 다 녹은 건지 어떻게 된 건지 펑퍼짐하...
# 224  숭실대입구역 스타벅스숭실대점                           주말 카운터 알바 완전 별로. 아는게 없는듯
# 225  숭실대입구역 스타벅스숭실대점  작년에.....있었던 일입니다....  텀블러 안에 미리 넣어 두었던 보이차 가루를...
# 226  숭실대입구역 스타벅스숭실대점                                                좋아요
# 227  숭실대입구역 스타벅스숭실대점                                              보통이에요
# 228  숭실대입구역 스타벅스숭실대점  블론드 서머 라떼 2일 전에 먹었는데 크림이 다 녹은 건지 어떻게 된 건지 펑퍼짐하...
# 229  숭실대입구역 스타벅스숭실대점                           주말 카운터 알바 완전 별로. 아는게 없는듯
# 230  숭실대입구역 스타벅스숭실대점  작년에.....있었던 일입니다....  텀블러 안에 미리 넣어 두었던 보이차 가루를...
# 231  숭실대입구역 스타벅스숭실대점                                                좋아요
# 232  숭실대입구역 스타벅스숭실대점                                              보통이에요
# 233  숭실대입구역 스타벅스숭실대점  블론드 서머 라떼 2일 전에 먹었는데 크림이 다 녹은 건지 어떻게 된 건지 펑퍼짐하...
# 234  숭실대입구역 스타벅스숭실대점                           주말 카운터 알바 완전 별로. 아는게 없는듯
# 235  숭실대입구역 스타벅스숭실대점  작년에.....있었던 일입니다....  텀블러 안에 미리 넣어 두었던 보이차 가루를...

# %%
rating_df.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe(105).csv')

# %%
User_ID_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe_User(105).csv')
item_img_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe_img(105).csv')
item_review_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lline7_cafe_review(105).csv')

# %%
ItemID_elem = rating_df['ItemID'].unique()
len(ItemID_elem)
# Out:
# 39

# %%
data.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_(1)105url.csv')
