# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from selenium.webdriver.common.keys import Keys
import pandas as pd
import math
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import json

# %%
data = pd.read_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7.csv')
data
# 카페 데이터만
data = data.loc[data['상권업종중분류명'] == '커피점/카페']  
data
# Out:
#        Unnamed: 0    상가업소번호         상호명       지점명 상권업종대분류코드 상권업종대분류명  \
# 24            270  20297127       카페오작교       NaN         Q       음식
# 25            282  23238698        들꽃누리       NaN         Q       음식
# 34            469  20017448         커피빈  코리아청담에스점         Q       음식
# 37            497  24327928  건대포토카페프린세스       NaN         Q       음식
# 47            586  20023467         커피빈  코리아청담성당점         Q       음식
# ...           ...       ...         ...       ...       ...      ...
# 12149      135223  17254892    안다미로팬케이크       NaN         Q       음식
# 12150      135226  17252483        초코라떼      건대역점         Q       음식
# 12152      135251  17207986          카페     동네항동점         Q       음식
# 12159      135345  17243108     코끼리키즈까페       NaN         Q       음식
# 12170      135522  17249835      ON&OFF       NaN         Q       음식
#
#       상권업종중분류코드 상권업종중분류명 상권업종소분류코드     상권업종소분류명  ...   구우편번호   신우편번호  동정보  \
# 24          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135953  6070.0  NaN
# 25          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  150070  7412.0  NaN
# 34          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135955  6011.0  NaN
# 37          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143190  5073.0  NaN
# 47          Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135953  6074.0  NaN
# ...         ...      ...       ...          ...  ...     ...     ...  ...
# 12149       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143915  5012.0  NaN
# 12150       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  143854  5066.0  NaN
# 12152       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  152140  8362.0  NaN
# 12159       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  152815  8352.0  NaN
# 12170       Q12   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135814  6044.0  NaN
#
#        층정보  호정보          경도         위도               역명          거리 카카오url
# 24       1  NaN  127.049293  37.522951           7호선 청담  398.760647    NaN
# 25       1  NaN  126.898633  37.497079     7호선 대림(구로구청)  368.888504    NaN
# 34       1  109  127.047216  37.525250           7호선 청담  675.120538    NaN
# 37       1  NaN  127.068745  37.539802         7호선 건대입구   60.940672    NaN
# 47       2  NaN  127.050021  37.519902           7호선 청담  229.848907    NaN
# ...    ...  ...         ...        ...              ...         ...    ...
# 12149  NaN  NaN  127.071012  37.544992  7호선 어린이대공원(세종대)  355.054760    NaN
# 12150    7  NaN  127.074625  37.538335  7호선 어린이대공원(세종대)  592.981894    NaN
# 12152    1  NaN  126.821130  37.482852   7호선 온수(성공회대입구)  567.166627    NaN
# 12159    2  NaN  126.854261  37.486412        7호선 광명사거리  478.139096    NaN
# 12170    6  NaN  127.021176  37.512863           7호선 학동  125.163948    NaN
#
# [1879 rows x 43 columns]

# %%
data = data[["상호명","상권업종중분류명","상권업종소분류명","도로명주소","역명","거리","카카오url"]]
data["역"] = data["역명"].apply(lambda x : x.split(" ")[1])
data["역"] = data["역"].apply(lambda x : x.split("(")[0])
data["검색어"] = data.apply(lambda x : x["역"] + "역 " + str(x["상호명"]),axis=1)
data
# Out:
#               상호명 상권업종중분류명     상권업종소분류명                 도로명주소  \
# 24          카페오작교   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로92길 26
# 25           들꽃누리   커피점/카페  커피전문점/카페/다방    서울특별시 영등포구 대림로 183
# 34            커피빈   커피점/카페  커피전문점/카페/다방    서울특별시 강남구 압구정로 461
# 37     건대포토카페프린세스   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 동일로20길 98
# 47            커피빈   커피점/카페  커피전문점/카페/다방     서울특별시 강남구 삼성로 716
# ...           ...      ...          ...                   ...
# 12149    안다미로팬케이크   커피점/카페  커피전문점/카페/다방      서울특별시 광진구 군자로 19
# 12150        초코라떼   커피점/카페  커피전문점/카페/다방   서울특별시 광진구 아차산로36길 5
# 12152          카페   커피점/카페  커피전문점/카페/다방   서울특별시 구로구 연동로11길 19
# 12159     코끼리키즈까페   커피점/카페  커피전문점/카페/다방    서울특별시 구로구 개봉로3길 36
# 12170      ON&OFF   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 강남대로136길 6
#
#                     역명          거리  카카오url       역               검색어
# 24              7호선 청담  398.760647     NaN      청담         청담역 카페오작교
# 25        7호선 대림(구로구청)  368.888504     NaN      대림          대림역 들꽃누리
# 34              7호선 청담  675.120538     NaN      청담           청담역 커피빈
# 37            7호선 건대입구   60.940672     NaN    건대입구  건대입구역 건대포토카페프린세스
# 47              7호선 청담  229.848907     NaN      청담           청담역 커피빈
# ...                ...         ...     ...     ...               ...
# 12149  7호선 어린이대공원(세종대)  355.054760     NaN  어린이대공원  어린이대공원역 안다미로팬케이크
# 12150  7호선 어린이대공원(세종대)  592.981894     NaN  어린이대공원      어린이대공원역 초코라떼
# 12152   7호선 온수(성공회대입구)  567.166627     NaN      온수            온수역 카페
# 12159        7호선 광명사거리  478.139096     NaN   광명사거리    광명사거리역 코끼리키즈까페
# 12170           7호선 학동  125.163948     NaN      학동        학동역 ON&OFF
#
# [1879 rows x 9 columns]

# %%
items = data["검색어"]
items
# Out:
# 24              청담역 카페오작교
# 25               대림역 들꽃누리
# 34                청담역 커피빈
# 37       건대입구역 건대포토카페프린세스
# 47                청담역 커피빈
#                ...
# 12149    어린이대공원역 안다미로팬케이크
# 12150        어린이대공원역 초코라떼
# 12152              온수역 카페
# 12159      광명사거리역 코끼리키즈까페
# 12170          학동역 ON&OFF
# Name: 검색어, Length: 1879, dtype: object

# %%
rating_df = pd.DataFrame(columns = ["UserID","ItemID","Rating","Timestamp"])
img_elem = pd.DataFrame(columns = ["ItemID","img_url"])
review_elem = pd.DataFrame(columns = ["ItemID", "review"])
user_review_id = {}
review_json = {}
image_json = {}

# %%
# 드라이버 구동
driver = webdriver.Chrome(executable_path='C:/Users/정예림/Desktop/추천시스템 프로젝트/chromedriver.exe')
# 창 크기 최대화
driver.maximize_window() 



count = 0
current = 0
indexing = 0
goal = len(items)
for item in items :
    current += 1
    print('진행상황 : ', current,'/',goal,sep="")
    # 리뷰가 없을 때의 코드
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    time.sleep(2)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        time.sleep(2)
        content_url = reviewbutton.get_attribute("href") 
        #상세보기 URL수집
        url = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').get_attribute('href')
        data.iloc[indexing,-3] = url
        print(url)
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        time.sleep(20)
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                try:
                    row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_ur}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)

                    time.sleep(1)
                except:
                    row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_url}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    time.sleep(1)

                
                    
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,500):
                time.sleep(3)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        try:
                            row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                            
                        except:
                            row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                        
                        
                            
        except:
            print("더 이상 리뷰 존재 X")
            driver.close()
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        data.iloc[indexing,-3] = None
        print("식당 존재 x")
    
    indexing += 1
# Out:
# 진행상황 : 1/1879
# 식당 존재 x
# 진행상황 : 2/1879
# 식당 존재 x
# 진행상황 : 3/1879
# 식당 존재
# https://place.map.kakao.com/8103501
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 4/1879
# 식당 존재 x
# 진행상황 : 5/1879
# 식당 존재
# https://place.map.kakao.com/8103501
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 6/1879
# 식당 존재
# https://place.map.kakao.com/10060027
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 7/1879
# 식당 존재 x
# 진행상황 : 8/1879
# 식당 존재 x
# 진행상황 : 9/1879
# 식당 존재
# https://place.map.kakao.com/746969844
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 10/1879
# 식당 존재
# https://place.map.kakao.com/1691675030
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 11/1879
# 식당 존재
# https://place.map.kakao.com/24637865
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 12/1879
# 식당 존재
# https://place.map.kakao.com/778181828
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 13/1879
# 식당 존재 x
# 진행상황 : 14/1879
# 식당 존재
# https://place.map.kakao.com/26561658
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 15/1879
# 식당 존재 x
# 진행상황 : 16/1879
# 식당 존재
# https://place.map.kakao.com/23556852
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 :
# 식당 존재 x
# 진행상황 : 135/1879
# 식당 존재 x
# 진행상황 : 136/1879
# 식당 존재 x
# 진행상황 : 137/1879
# 식당 존재 x
# 진행상황 : 138/1879
# 식당 존재 x
# 진행상황 : 139/1879
# 식당 존재 x
# 진행상황 : 140/1879
# 식당 존재 x
# 진행상황 : 141/1879
# 식당 존재 x
# 진행상황 : 142/1879
# 식당 존재 x
# 진행상황 : 143/1879
# 식당 존재
# https://place.map.kakao.com/767487353
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 144/1879
# 식당 존재
# https://place.map.kakao.com/767487353
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 145/1879
# 식당 존재
# https://place.map.kakao.com/27049130
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 146/1879
# 식당 존재
# https://place.map.kakao.com/786746214
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 147/1879
# 식당 존재
# https://place.map.kakao.com/239912045
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 148/1879
# 식당 존재
# https://place.map.kakao.com/418082712
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 149/1879
# 식당 존재
# https://place.map.kakao.com/996246139
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 150/1879
# 식당 존재 x
# 진행상황 : 151/1879
# 식당 존재
# https://place.map.kakao.com/1965447540
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 152/1879
# 식당 존재
# https://place.map.kakao.com/15899307
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 153/1879
# 식당 존재 x
# 진행상황 : 154/1879
# 식당 존재
# https://place.map.kakao.com/10822361
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 155/1879
# 식당 존재
# https://place.map.kakao.com/44736686
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 156/1879
# 식당 존재
# https://place.map.kakao.com/8547265
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 157/1879
# 식당 존재
# https://place.map.kakao.com/19925444
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 158/1879
# 식당 존재
# https://place.map.kakao.com/12508558
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 159/1879
# 식당 존재
# https://place.map.kakao.com/19244732
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 160/1879
# 식당 존재
# https://place.map.kakao.com/26598573
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 161/1879
# 식당 존재 x
# 진행상황 : 162/1879
# 식당 존재 x
# 진행상황 : 163/1879
# 식당 존재
# https://place.map.kakao.com/89150246
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 164/1879
# 식당 존재 x
# 진행상황 : 165/1879
# 식당 존재
# https://place.map.kakao.com/16590891
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 166/1879
# 식당 존재
# https://place.map.kakao.com/1722783091
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 167/1879
# 식당 존재 x
# 진행상황 : 168/1879
# 식당 존재
# https://place.map.kakao.com/498351117
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 169/1879
# 식당 존재
# https://place.map.kakao.com/26966074
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 170/1879
# 식당 존재
# https://place.map.kakao.com/872257394
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 171/1879
# 식당 존재
# https://place.map.kakao.com/17736671
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 172/1879
# 식당 존재 x
# 진행상황 : 173/1879
# 식당 존재 x
# 진행상황 : 174/1879
# 식당 존재
# https://place.map.kakao.com/25550990
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 175/1879
# 식당 존재 x
# 진행상황 : 176/1879
# 식당 존재 x
# 진행상황 : 177/1879
# 식당 존재 x
# 진행상황 : 178/1879
# 식당 존재
# https://place.map.kakao.com/227408043
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 179/1879
# 식당 존재
# https://place.map.kakao.com/1079374522
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 180/1879
# 식당 존재 x
# 진행상황 : 181/1879
# 식당 존재
# https://place.map.kakao.com/2112072913
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 182/1879
# 식당 존재
# https://place.map.kakao.com/540832879
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 183/1879
# 식당 존재
# https://place.map.kakao.com/112126679
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 184/1879
# 식당 존재 x
# 진행상황 : 185/1879
# 식당 존재
# https://place.map.kakao.com/489503293
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 186/1879
# 식당 존재
# https://place.map.kakao.com/130331341
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 187/1879
# 식당 존재
# https://place.map.kakao.com/872257394
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 188/1879
# 식당 존재 x
# 진행상황 : 189/1879
# 식당 존재
# https://place.map.kakao.com/17806448
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 190/1879
# 식당 존재
# https://place.map.kakao.com/911369063
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 191/1879
# 식당 존재
# https://place.map.kakao.com/1733931372
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 192/1879
# 식당 존재
# https://place.map.kakao.com/2018654232
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 193/1879
# 식당 존재
# https://place.map.kakao.com/2018654232
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 194/1879
# 식당 존재
# https://place.map.kakao.com/1530418128
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 195/1879
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-9-a363dfa393a7> in <module>
#      14     print('진행상황 : ', current,'/',goal,sep="")
#      15     # 리뷰가 없을 때의 코드
# ---> 16     driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
#      17     searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
#      18     searchbox.send_keys(item)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: chrome=90.0.4430.93)

# %%
rating_df
# Out:
#       UserID   ItemID Rating    Timestamp
# 0    151kktb  청담역 커피빈     5점  2021.04.02.
# 1       None  청담역 커피빈   None  2013.12.25.
# 2             청담역 커피빈     5점  2016.06.09.
# 3    151kktb  청담역 커피빈     5점  2021.04.02.
# 4       None  청담역 커피빈   None  2013.12.25.
# ..       ...      ...    ...          ...
# 441   gf37t7  사가정역 카페     1점  2019.07.11.
# 442   e30co9  사가정역 카페     5점  2020.09.20.
# 443  1bflvv2  사가정역 카페     5점  2020.09.10.
# 444   ed7n2u  사가정역 카페     5점  2020.08.16.
# 445   gf37t7  사가정역 카페     1점  2019.07.11.
#
# [446 rows x 4 columns]

# %%
img_elem
# Out:
#       ItemID img_url
# 0    청담역 커피빈    None
# 1    청담역 커피빈      []
# 2    청담역 커피빈    None
# 3    청담역 커피빈    None
# 4    청담역 커피빈      []
# ..       ...     ...
# 441  사가정역 카페    None
# 442  사가정역 카페    None
# 443  사가정역 카페    None
# 444  사가정역 카페    None
# 445  사가정역 카페    None
#
# [446 rows x 2 columns]

# %%
data
# Out:
#                    상호명 상권업종중분류명     상권업종소분류명                  도로명주소  \
# 0                 이레식당       한식    한식/백반/한정식    서울특별시 동작구 성대로31길 71
# 1                 피자스쿨    패스트푸드         피자전문     서울특별시 영등포구 대림로 247
# 2                 장터국밥       한식      해장국/감자탕  서울특별시 도봉구 도봉로180나길 41
# 3      서울과학기술대학교제2학생식당    기타음식업  구내식당/자급식음식점      서울특별시 노원구 공릉로 232
# 4            초밥&참치전문점연   일식/수산물        참치전문점      서울특별시 광진구 능동로 179
# ...                ...      ...          ...                    ...
# 12182             벚꽃스시   일식/수산물     음식점-초밥전문    서울특별시 동작구 상도로30길 40
# 12183          생고기김치찌개       한식       갈비/삼겹살  서울특별시 구로구 개봉로11길 18-1
# 12184              피굽남       한식    한식/백반/한정식   서울특별시 중랑구 용마산로51길 45
# 12185            왕십리곱창       한식     곱창/양구이전문    서울특별시 중랑구 동일로163길 8
# 12186            기찻길풍경       한식     곱창/양구이전문    서울특별시 노원구 공릉로39길 21
#
#                     역명          거리                                카카오url  \
# 0             7호선 장승배기  252.070018  https://place.map.kakao.com/16821812
# 1         7호선 대림(구로구청)  655.825278  https://place.map.kakao.com/16300615
# 2              7호선 도봉산  490.786535                                  None
# 3      7호선 공릉(서울과학기술대)  651.158559                                  None
# 4      7호선 어린이대공원(세종대)   59.203796  https://place.map.kakao.com/21086077
# ...                ...         ...                                   ...
# 12182         7호선 장승배기  429.306668                                   NaN
# 12183        7호선 광명사거리  588.584222                                   NaN
# 12184          7호선 용마산  471.931015                                   NaN
# 12185           7호선 먹골  135.612799                                   NaN
# 12186         7호선 태릉입구  461.771739                                   NaN
#
#             역                  검색어
# 0        장승배기           장승배기역 이레식당
# 1          대림             대림역 피자스쿨
# 2         도봉산            도봉산역 장터국밥
# 3          공릉  공릉역 서울과학기술대학교제2학생식당
# 4      어린이대공원    어린이대공원역 초밥&참치전문점연
# ...       ...                  ...
# 12182    장승배기           장승배기역 벚꽃스시
# 12183   광명사거리       광명사거리역 생고기김치찌개
# 12184     용마산             용마산역 피굽남
# 12185      먹골            먹골역 왕십리곱창
# 12186    태릉입구          태릉입구역 기찻길풍경
#
# [12187 rows x 9 columns]

# %%
img_elem
# Out:
#              ItemID img_url
# 0          대림역 피자스쿨    None
# 1          대림역 피자스쿨    None
# 2          대림역 피자스쿨    None
# 3         중화역 미스터피자    None
# 4         중화역 미스터피자    None
# ...             ...     ...
# 1446  어린이대공원역 뉴욕떡볶이      []
# 1447  어린이대공원역 뉴욕떡볶이    None
# 1448  어린이대공원역 뉴욕떡볶이    None
# 1449  어린이대공원역 뉴욕떡볶이    None
# 1450  어린이대공원역 뉴욕떡볶이    None
#
# [1451 rows x 2 columns]

# %%
rating_df
# Out:
#        UserID         ItemID Rating    Timestamp
# 0     12p3llk       대림역 피자스쿨     5점  2021.02.26.
# 1      7ki33p       대림역 피자스쿨     5점  2019.07.27.
# 2                   대림역 피자스쿨     5점  2011.02.03.
# 3     19kn92r      중화역 미스터피자     5점  2020.07.04.
# 4     1950bi0      중화역 미스터피자     5점  2020.06.13.
# ...       ...            ...    ...          ...
# 1446     None  어린이대공원역 뉴욕떡볶이   None  2018.03.01.
# 1447     None  어린이대공원역 뉴욕떡볶이   None  2016.12.11.
# 1448           어린이대공원역 뉴욕떡볶이     5점  2017.03.24.
# 1449           어린이대공원역 뉴욕떡볶이     5점  2016.10.16.
# 1450           어린이대공원역 뉴욕떡볶이     5점  2016.06.28.
#
# [1451 rows x 4 columns]

# %%
review_elem
# Out:
#              ItemID                                             review
# 0          대림역 피자스쿨                                               최고예요
# 1          대림역 피자스쿨                                      깔끔하고 맛있고 친절하심
# 2          대림역 피자스쿨  테이크아웃 피자전문점! 정말 맛있어서 자주 이용하는 곳~ 저렴하고 친절해요 추천합니...
# 3         중화역 미스터피자  런치피자부페 갔다가 맛있는 피자 풍성하게 먹었어요. 사람도 많이 없고 한산해서 여유...
# 4         중화역 미스터피자  요즈음 코로나19도 있었고 6월 들어 날씨도 맘에 들지않고 등등 외부환경이 그리 녹...
# ...             ...                                                ...
# 1446  어린이대공원역 뉴욕떡볶이                                     근처에서  나름 소문난맛집
# 1447  어린이대공원역 뉴욕떡볶이                              근처에서 제일 맛있다  순대도 맛있음
# 1448  어린이대공원역 뉴욕떡볶이                     아드님인거 같은데 친절하네요 어머니는 뒷방으로 빠지세요
# 1449  어린이대공원역 뉴욕떡볶이                                            너무맛있어요
# 1450  어린이대공원역 뉴욕떡볶이                                             너무맛있어요
#
# [1451 rows x 2 columns]

# %%
img_elem.head()
# Out:
#       ItemID img_url
# 0   대림역 피자스쿨    None
# 1   대림역 피자스쿨    None
# 2   대림역 피자스쿨    None
# 3  중화역 미스터피자    None
# 4  중화역 미스터피자    None

# %%
ItemID_elem = rating_df['ItemID'].unique()

for k in range(len(ItemID_elem)) :
    User_ID_elem = rating_df.loc[rating_df['ItemID'] == ItemID_elem[k]]
    Uder_ID_elem = User_ID_elem[['UserID','ItemID']]
print(User_ID_elem)





ItemID_elem = img_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_img_elem = img_elem.loc[img_elem['ItemID'] == ItemID_elem[j]]
print(item_img_elem)



ItemID_elem = review_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_review_elem = review_elem.loc[review_elem['ItemID'] == ItemID_elem[j]]
print(item_review_elem)
# Out:
#       UserID   ItemID Rating    Timestamp
# 438   e30co9  사가정역 카페     5점  2020.09.20.
# 439  1bflvv2  사가정역 카페     5점  2020.09.10.
# 440   ed7n2u  사가정역 카페     5점  2020.08.16.
# 441   gf37t7  사가정역 카페     1점  2019.07.11.
# 442   e30co9  사가정역 카페     5점  2020.09.20.
# 443  1bflvv2  사가정역 카페     5점  2020.09.10.
# 444   ed7n2u  사가정역 카페     5점  2020.08.16.
# 445   gf37t7  사가정역 카페     1점  2019.07.11.
#       ItemID img_url
# 438  사가정역 카페    None
# 439  사가정역 카페    None
# 440  사가정역 카페    None
# 441  사가정역 카페    None
# 442  사가정역 카페    None
# 443  사가정역 카페    None
# 444  사가정역 카페    None
# 445  사가정역 카페    None
#       ItemID                                             review
# 438  사가정역 카페                                   장수 아메리카노 맛있네요~^^
# 439  사가정역 카페  분위기도 좋은데 커피까지 너무 맛있어요. 딱 하나 아쉬웠던 점이 실내에서 마스크 안...
# 440  사가정역 카페                                      커피가 고소하고 달달해요
# 441  사가정역 카페                         12:15 왔는데 문 잠겨있음 전화하고 가시길
# 442  사가정역 카페                                   장수 아메리카노 맛있네요~^^
# 443  사가정역 카페  분위기도 좋은데 커피까지 너무 맛있어요. 딱 하나 아쉬웠던 점이 실내에서 마스크 안...
# 444  사가정역 카페                                      커피가 고소하고 달달해요
# 445  사가정역 카페                         12:15 왔는데 문 잠겨있음 전화하고 가시길

# %%
rating_df.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe(195).csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc1a37ab1bd7> in <module>
# ----> 1 rating_df.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe(195).csv')
#
# NameError: name 'rating_df' is not defined

# %%
User_ID_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe_User(195).csv')
item_img_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_cafe_img(195).csv')
item_review_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lline7_cafe_review(195).csv')

# %%
ItemID_elem = rating_df['ItemID'].unique()
len(ItemID_elem)
# Out:
# 58

# %%
data.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/line7_(1)263url.csv')
