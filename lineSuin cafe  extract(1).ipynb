# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from selenium.webdriver.common.keys import Keys
import pandas as pd
import math
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import json

# %%
data = pd.read_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin.csv')
data
# 카페 데이터만
data = data.loc[data['상권업종중분류명'] == '커피점/카페']  
data
# Out:
#       Unnamed: 0    상가업소번호      상호명       지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 3            182  25472959    노란고무줄       NaN         Q       음식       Q12
# 7            330  20296218     홈스테드  커피타워팰리스점         Q       음식       Q12
# 11           382  25390239    Manna       NaN         Q       음식       Q12
# 12           397  25964875     스타벅스       한티점         Q       음식       Q12
# 13           428  25363926    커피팩토리       NaN         Q       음식       Q12
# ...          ...       ...      ...       ...       ...      ...       ...
# 4578      135218  17252476     총알커피       NaN         Q       음식       Q12
# 4592      135511  17196732    컴포즈커피       대치점         Q       음식       Q12
# 4593      135523  17254647  스테이지246       NaN         Q       음식       Q12
# 4594      135525  17250772       카페      라스보드         Q       음식       Q12
# 4595      135526  17252508      MMN       NaN         Q       음식       Q12
#
#      상권업종중분류명 상권업종소분류코드     상권업종소분류명  ...   구우편번호   신우편번호  동정보  층정보  호정보  \
# 3      커피점/카페    Q12A01  커피전문점/카페/다방  ...  135280  6198.0  NaN    1  NaN
# 7      커피점/카페    Q12A01  커피전문점/카페/다방  ...  135270  6292.0  NaN  NaN  NaN
# 11     커피점/카페    Q12A03     생과일주스전문점  ...  135744  6367.0  NaN    2  NaN
# 12     커피점/카페    Q12A01  커피전문점/카페/다방  ...  135280  6206.0  NaN    6  NaN
# 13     커피점/카페    Q12A01  커피전문점/카페/다방  ...  135010  6055.0  NaN  NaN  NaN
# ...       ...       ...          ...  ...     ...     ...  ...  ...  ...
# 4578   커피점/카페    Q12A01  커피전문점/카페/다방  ...  133824  4768.0  NaN  NaN  NaN
# 4592   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135840  6194.0  NaN    1  107
# 4593   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135832  6098.0  NaN    4  NaN
# 4594   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135896  6017.0  NaN    4  NaN
# 4595   커피점/카페    Q12A01  커피전문점/카페/다방  ...  135949  6065.0  NaN  NaN  NaN
#
#               경도         위도         역명          거리 카카오url
# 3     127.050045  37.502899      분당 한티  547.173123    NaN
# 7     127.053198  37.488742      분당 도곡  243.138693    NaN
# 11    127.103094  37.487311      분당 수서  139.233515    NaN
# 12    127.053715  37.497946      분당 한티  149.558597    NaN
# 13    127.037622  37.521739    분당 강남구청  509.770567    NaN
# ...          ...        ...        ...         ...    ...
# 4578  127.044089  37.546850     분당 서울숲  204.699780    NaN
# 4592  127.053512  37.505072      분당 한티  597.839979    NaN
# 4593  127.036546  37.514765    분당 강남구청  550.784894    NaN
# 4594  127.036670  37.527110  분당 압구정로데오  531.075407    NaN
# 4595  127.043934  37.520889    분당 강남구청  385.669093    NaN
#
# [826 rows x 43 columns]

# %%
data = data[["상호명","상권업종중분류명","상권업종소분류명","도로명주소","역명","거리","카카오url"]]
data["역"] = data["역명"].apply(lambda x : x.split(" ")[1])
data["역"] = data["역"].apply(lambda x : x.split("(")[0])
data["검색어"] = data.apply(lambda x : x["역"] + "역 " + str(x["상호명"]),axis=1)
data
# Out:
#           상호명 상권업종중분류명     상권업종소분류명                 도로명주소         역명  \
# 3       노란고무줄   커피점/카페  커피전문점/카페/다방     서울특별시 강남구 선릉로 424      분당 한티
# 7        홈스테드   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 언주로30길 39      분당 도곡
# 11      Manna   커피점/카페     생과일주스전문점     서울특별시 강남구 광평로 280      분당 수서
# 12       스타벅스   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 선릉로64길 18      분당 한티
# 13      커피팩토리   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 도산대로50길 9    분당 강남구청
# ...       ...      ...          ...                   ...        ...
# 4578     총알커피   커피점/카페  커피전문점/카페/다방  서울특별시 성동구 왕십리로5길 9-2     분당 서울숲
# 4592    컴포즈커피   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 선릉로90길 56      분당 한티
# 4593  스테이지246   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 언주로130길 12    분당 강남구청
# 4594       카페   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 언주로172길 36  분당 압구정로데오
# 4595      MMN   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로66길 39    분당 강남구청
#
#               거리  카카오url       역            검색어
# 3     547.173123     NaN      한티      한티역 노란고무줄
# 7     243.138693     NaN      도곡       도곡역 홈스테드
# 11    139.233515     NaN      수서      수서역 Manna
# 12    149.558597     NaN      한티       한티역 스타벅스
# 13    509.770567     NaN    강남구청    강남구청역 커피팩토리
# ...          ...     ...     ...            ...
# 4578  204.699780     NaN     서울숲      서울숲역 총알커피
# 4592  597.839979     NaN      한티      한티역 컴포즈커피
# 4593  550.784894     NaN    강남구청  강남구청역 스테이지246
# 4594  531.075407     NaN  압구정로데오     압구정로데오역 카페
# 4595  385.669093     NaN    강남구청      강남구청역 MMN
#
# [826 rows x 9 columns]

# %%
items = data["검색어"]
items
# Out:
# 3           한티역 노란고무줄
# 7            도곡역 홈스테드
# 11          수서역 Manna
# 12           한티역 스타벅스
# 13        강남구청역 커피팩토리
#             ...
# 4578        서울숲역 총알커피
# 4592        한티역 컴포즈커피
# 4593    강남구청역 스테이지246
# 4594       압구정로데오역 카페
# 4595        강남구청역 MMN
# Name: 검색어, Length: 826, dtype: object

# %%
rating_df = pd.DataFrame(columns = ["UserID","ItemID","Rating","Timestamp"])
img_elem = pd.DataFrame(columns = ["ItemID","img_url"])
review_elem = pd.DataFrame(columns = ["ItemID", "review"])
user_review_id = {}
review_json = {}
image_json = {}

# %%
# 드라이버 구동
driver = webdriver.Chrome(executable_path='C:/Users/정예림/Desktop/추천시스템 프로젝트/chromedriver.exe')
# 창 크기 최대화
driver.maximize_window() 



count = 0
current = 0
indexing = 0
goal = len(items)
for item in items :
    current += 1
    print('진행상황 : ', current,'/',goal,sep="")
    # 리뷰가 없을 때의 코드
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    time.sleep(2)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        time.sleep(2)
        content_url = reviewbutton.get_attribute("href") 
        #상세보기 URL수집
        url = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').get_attribute('href')
        data.iloc[indexing,-3] = url
        print(url)
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        time.sleep(20)
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                try:
                    row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_ur}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)

                    time.sleep(1)
                except:
                    row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                    row = pd.DataFrame(row, index=[i])
                    rating_df = rating_df.append(row,ignore_index=True)
                    review_row = {"ItemID" : item, "review" : user_review[0].text}
                    review_row = pd.DataFrame(review_row, index=[i])
                    review_elem = review_elem.append(review_row, ignore_index = True)
                    try :
                        img_row = {"ItemID" : item, "img_url" : img_url}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    except :
                        img_row = {"ItemID" : item, "img_url" : None}
                        img_row = pd.DataFrame(img_row, index=[i])
                        img_elem = img_elem.append(img_row, ignore_index=True)
                    time.sleep(1)

                
                    
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,500):
                time.sleep(3)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        try:
                            row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating[0].text,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                            
                        except:
                            row = {"UserID":None,"ItemID":item,"Rating":None,"Timestamp":timestamp[0].text}
                            row = pd.DataFrame(row, index=[i])
                            rating_df = rating_df.append(row,ignore_index=True)
                            review_row = {"ItemID" : item, "review" : user_review[0].text}
                            review_row = pd.DataFrame(review_row, index=[i])
                            review_elem = review_elem.append(review_row, ignore_index = True)
                            try :
                                img_row = {"ItemID" : item, "img_url" : img_url}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            except :
                                img_row = {"ItemID" : item, "img_url" : None}
                                img_row = pd.DataFrame(img_row, index=[i])
                                img_elem = img_elem.append(img_row, ignore_index=True)
                            time.sleep(1)
                        
                        
                            
        except:
            print("더 이상 리뷰 존재 X")
            driver.close()
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        data.iloc[indexing,-3] = None
        print("식당 존재 x")
    
    indexing += 1
# Out:
# 진행상황 : 1/826
# 식당 존재 x
# 진행상황 : 2/826
# 식당 존재
# https://place.map.kakao.com/18780447
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 3/826
# 식당 존재 x
# 진행상황 : 4/826
# 식당 존재
# https://place.map.kakao.com/22178753
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 5/826
# 식당 존재
# https://place.map.kakao.com/27513867
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 6/826
# 식당 존재
# https://place.map.kakao.com/13578068
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 7/826
# 식당 존재
# https://place.map.kakao.com/1247060404
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 8/826
# 식당 존재
# https://place.map.kakao.com/22873952
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 9/826
# 식당 존재
# https://place.map.kakao.com/18694448
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 10/826
# 식당 존재
# https://place.map.kakao.com/21414605
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 11/826
# 식당 존재
# https://place.map.kakao.com/3499104
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 12/826
# 식당 존재 x
# 진행상황 : 13/826
# 식당 존재 x
# 진행상황 : 14/826
# 식당 존재 x
# 진행상황 : 15/826
# 식당 존재
# https://place.map.kakao.com/13030482
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 16/826
# 식당 존재
# https://place.map.kakao.com/27244389
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 17/826
# 식당 존재 x
# 진행상황 : 18/826
# 식당 존재
# https://place.map.kakao.com/20613624
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 19/826
# 식당 존재
# https://place.map.kakao.com/12744384
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 20/826
# 식당 존재 x
# 진행상황 : 21/826
# 식당 존재
# https://place.map.kakao.com/17419369
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 22/826
# 식당 존재
# https://place.map.kakao.com/205188976
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 23/826
# 식당 존재
# https://place.map.kakao.com/21074941
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 24/826
# 식당 존재
# https://place.map.kakao.com/27543243
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 25/826
# 식당 존재
# https://place.map.kakao.com/8112721
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 26/826
# 식당 존재 x
# 진행상황 : 27/826
# 식당 존재 x
# 진행상황 : 28/826
# 식당 존재 x
# 진행상황 : 29/826
# 식당 존재 x
# 진행상황 : 30/826
# 식당 존재
# https://place.map.kakao.com/1165137776
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 31/826
# 식당 존재
# https://place.map.kakao.com/162634427
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 32/826
# 식당 존재
# https://place.map.kakao.com/362215093
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 33/826
# 식당 존재 x
# 진행상황 : 34/826
# 식당 존재 x
# 진행상황 : 35/826
# 식당 존재 x
# 진행상황 : 36/826
# 식당 존재
# https://place.map.kakao.com/16999316
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 37/826
# 식당 존재
# https://place.map.kakao.com/760649273
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 38/826
# 식당 존재
# https://place.map.kakao.com/505665583
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 39/826
# 식당 존재
# https://place.map.kakao.com/292873368
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 40/826
# 식당 존재 x
# 진행상황 : 41/826
# 식당 존재
# https://place.map.kakao.com/1633984565
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 42/826
# 식당 존재 x
# 진행상황 : 43/826
# 식당 존재 x
# 진행상황 : 44/826
# 식당 존재 x
# 진행상황 : 45/826
# 식당 존재 x
# 진행상황 : 46/826
# 식당 존재
# https://place.map.kakao.com/1767157280
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 47/826
# 식당 존재 x
# 진행상황 : 48/826
# 식당 존재 x
# 진행상황 : 49/826
# 식당 존재
# https://place.map.kakao.com/1311232536
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 50/826
# 식당 존재
# https://place.map.kakao.com/10534102
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 51/826
# 식당 존재 x
# 진행상황 : 52/826
# 식당 존재
# https://place.map.kakao.com/1407306632
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 53/826
# 식당 존재
# https://place.map.kakao.com/1113392396
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 54/826
# 식당 존재 x
# 진행상황 : 55/826
# 식당 존재 x
# 진행상황 : 56/826
# 식당 존재
# https://place.map.kakao.com/25738844
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 57/826
# 식당 존재
# https://place.map.kakao.com/9483453
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 58/826
# 식당 존재
# https://place.map.kakao.com/8112721
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 59/826
# 식당 존재 x
# 진행상황 : 60/826
# 식당 존재 x
# 진행상황 : 61/826
# 식당 존재
# https://place.map.kakao.com/852147672
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 62/826
# 식당 존재
# https://place.map.kakao.com/21074941
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 63/826
# 식당 존재
# https://place.map.kakao.com/21418712
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 64/826
# 식당 존재 x
# 진행상황 : 65/826
# 식당 존재
# https://place.map.kakao.com/21527351
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 66/826
# 식당 존재 x
# 진행상황 : 67/826
# 식당 존재
# https://place.map.kakao.com/108813563
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 68/826
# 식당 존재 x
# 진행상황 : 69/826
# 식당 존재
# https://place.map.kakao.com/8112555
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 70/826
# 식당 존재
# https://place.map.kakao.com/1329790187
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 71/826
# 식당 존재 x
# 진행상황 : 72/826
# 식당 존재
# https://place.map.kakao.com/13049428
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 73/826
# 식당 존재
# https://place.map.kakao.com/966027248
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 74/826
# 식당 존재
# https://place.map.kakao.com/1284321553
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 75/826
# 식당 존재
# https://place.map.kakao.com/26420362
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 76/826
# 식당 존재 x
# 진행상황 : 77/826
# 식당 존재 x
# 진행상황 : 78/826
# 식당 존재 x
# 진행상황 : 79/826
# 식당 존재 x
# 진행상황 : 80/826
# 식당 존재 x
# 진행상황 : 81/826
# 식당 존재
# https://place.map.kakao.com/27096055
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 82/826
# 식당 존재 x
# 진행상황 : 83/826
# 식당 존재
# https://place.map.kakao.com/8105442
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 84/826
# 식당 존재 x
# 진행상황 : 85/826
# 식당 존재
# https://place.map.kakao.com/17341786
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 86/826
# 식당 존재
# https://place.map.kakao.com/585302548
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 87/826
# 식당 존재
# https://place.map.kakao.com/27099510
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 88/826
# 식당 존재 x
# 진행상황 : 89/826
# 식당 존재 x
# 진행상황 : 90/826
# 식당 존재
# https://place.map.kakao.com/1197164754
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 91/826
# 식당 존재
# https://place.map.kakao.com/231577139
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 92/826
# 식당 존재
# https://place.map.kakao.com/8112555
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 93/826
# 식당 존재
# https://place.map.kakao.com/19153490
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 94/826
# 식당 존재
# https://place.map.kakao.com/811921842
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 95/826
# 식당 존재
# https://place.map.kakao.com/21319804
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 96/826
# 식당 존재
# https://place.map.kakao.com/26772607
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 97/826
# 식당 존재 x
# 진행상황 : 98/826
# 식당 존재
# https://place.map.kakao.com/13335864
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 99/826
# 식당 존재
# https://place.map.kakao.com/1507884823
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 100/826
# 식당 존재
# https://place.map.kakao.com/1581911343
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 101/826
# 식당 존재
# https://place.map.kakao.com/9467298
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 102/826
# 식당 존재
# https://place.map.kakao.com/221524142
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 103/826
# 식당 존재 x
# 진행상황 : 104/826
# 식당 존재
# https://place.map.kakao.com/179244712
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 105/826
# 식당 존재
# https://place.map.kakao.com/18197885
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 106/826
# 식당 존재 x
# 진행상황 : 107/826
# 식당 존재 x
# 진행상황 : 108/826
# 식당 존재
# https://place.map.kakao.com/1652741366
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 109/826
# 식당 존재
# https://place.map.kakao.com/1272580700
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 110/826
# 식당 존재
# https://place.map.kakao.com/1066616004
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 111/826
# 식당 존재
# https://place.map.kakao.com/1849426207
# 3
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 112/826
# 식당 존재
# https://place.map.kakao.com/13049428
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 113/826
# 식당 존재
# https://place.map.kakao.com/22178753
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 114/826
# 식당 존재
# https://place.map.kakao.com/13314189
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 115/826
# 식당 존재
# https://place.map.kakao.com/1115678762
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 116/826
# 식당 존재
# https://place.map.kakao.com/1818342272
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 117/826
# 식당 존재
# https://place.map.kakao.com/231920851
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 118/826
# 식당 존재 x
# 진행상황 : 119/826
# 식당 존재
# https://place.map.kakao.com/1564811703
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 120/826
# 식당 존재
# https://place.map.kakao.com/1530215201
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 121/826
# 식당 존재
# https://place.map.kakao.com/705457660
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 122/826
# 식당 존재
# https://place.map.kakao.com/2140311573
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 123/826
# 식당 존재
# https://place.map.kakao.com/26805861
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 124/826
# 식당 존재
# https://place.map.kakao.com/1996014742
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 125/826
# 식당 존재 x
# 진행상황 : 126/826
# 식당 존재
# https://place.map.kakao.com/27394639
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 127/826
# 식당 존재
# https://place.map.kakao.com/704177185
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 128/826
# 식당 존재 x
# 진행상황 : 129/826
# 식당 존재
# https://place.map.kakao.com/508456478
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 130/826
# 식당 존재 x
# 진행상황 : 131/826
# 식당 존재
# https://place.map.kakao.com/320019021
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 132/826
# 식당 존재
# https://place.map.kakao.com/137252852
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 133/826
# 식당 존재 x
# 진행상황 : 134/826
# 식당 존재
# https://place.map.kakao.com/1427527836
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 135/826
# 식당 존재
# https://place.map.kakao.com/23349752
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 136/826
# 식당 존재
# https://place.map.kakao.com/9196645
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 137/826
# 식당 존재
# https://place.map.kakao.com/255510384
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 138/826
# 식당 존재
# https://place.map.kakao.com/1795916471
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 139/826
# 식당 존재 x
# 진행상황 : 140/826
# 식당 존재
# https://place.map.kakao.com/1795916471
# 4
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 :
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 194/826
# 식당 존재 x
# 진행상황 : 195/826
# 식당 존재
# https://place.map.kakao.com/181069025
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 196/826
# 식당 존재
# https://place.map.kakao.com/703074194
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 197/826
# 식당 존재
# https://place.map.kakao.com/23106302
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 198/826
# 식당 존재 x
# 진행상황 : 199/826
# 식당 존재
# https://place.map.kakao.com/21442160
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 200/826
# 식당 존재 x
# 진행상황 : 201/826
# 식당 존재 x
# 진행상황 : 202/826
# 식당 존재 x
# 진행상황 : 203/826
# 식당 존재
# https://place.map.kakao.com/13724061
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 204/826
# 식당 존재 x
# 진행상황 : 205/826
# 식당 존재 x
# 진행상황 : 206/826
# 식당 존재 x
# 진행상황 : 207/826
# 식당 존재 x
# 진행상황 : 208/826
# 식당 존재 x
# 진행상황 : 209/826
# 식당 존재
# https://place.map.kakao.com/262308393
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 210/826
# 식당 존재 x
# 진행상황 : 211/826
# 식당 존재
# https://place.map.kakao.com/15686661
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 212/826
# 식당 존재 x
# 진행상황 : 213/826
# 식당 존재 x
# 진행상황 : 214/826
# 식당 존재 x
# 진행상황 : 215/826
# 식당 존재
# https://place.map.kakao.com/712064322
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 216/826
# 식당 존재 x
# 진행상황 : 217/826
# 식당 존재 x
# 진행상황 : 218/826
# 식당 존재
# https://place.map.kakao.com/20521970
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 219/826
# 식당 존재 x
# 진행상황 : 220/826
# 식당 존재 x
# 진행상황 : 221/826
# 식당 존재
# https://place.map.kakao.com/1741643929
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 222/826
# 식당 존재 x
# 진행상황 : 223/826
# 식당 존재 x
# 진행상황 : 224/826
# 식당 존재 x
# 진행상황 : 225/826
# 식당 존재 x
# 진행상황 : 226/826
# 식당 존재 x
# 진행상황 : 227/826
# 식당 존재
# https://place.map.kakao.com/13282630
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 228/826
# 식당 존재
# https://place.map.kakao.com/23902415
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 229/826
# 식당 존재 x
# 진행상황 : 230/826
# 식당 존재 x
# 진행상황 : 231/826
# 식당 존재
# https://place.map.kakao.com/781619494
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 232/826
# 식당 존재 x
# 진행상황 : 233/826
# 식당 존재 x
# 진행상황 : 234/826
# 식당 존재
# https://place.map.kakao.com/2128260199
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 235/826
# 식당 존재
# https://place.map.kakao.com/653345477
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 236/826
# 식당 존재 x
# 진행상황 : 237/826
# 식당 존재 x
# 진행상황 : 238/826
# 식당 존재 x
# 진행상황 : 239/826
# 식당 존재
# https://place.map.kakao.com/1697168139
# 1
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 240/826
# 식당 존재 x
# 진행상황 : 241/826
# 식당 존재
# https://place.map.kakao.com/171652459
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 242/826
# 식당 존재
# https://place.map.kakao.com/26336400
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 243/826
# 식당 존재
# https://place.map.kakao.com/17382244
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 244/826
# 식당 존재
# https://place.map.kakao.com/19244516
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 245/826
# 식당 존재 x
# 진행상황 : 246/826
# 식당 존재 x
# 진행상황 : 247/826
# 식당 존재
# https://realty.daum.net/home/apt/danjis/19589
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 248/826
# 식당 존재
# https://place.map.kakao.com/21325680
# 2
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 249/826
# 식당 존재
# https://place.map.kakao.com/1584578346
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 : 250/826
# 식당 존재 x
# 진행상황 : 251/826
# 식당 존재 x
# 진행상황 : 252/826
# 식당 존재
# https://place.map.kakao.com/1276276851
# 5
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 진행상황 :
# 진행상황 : 513/826
# 식당 존재 x
# 진행상황 : 514/826
# 식당 존재 x
# 진행상황 : 515/826
# 식당 존재 x
# 진행상황 : 516/826
# 식당 존재 x
# 진행상황 : 517/826
# 식당 존재 x
# 진행상황 : 518/826
# 식당 존재 x
# 진행상황 : 519/826
# 식당 존재 x
# 진행상황 : 520/826
# 식당 존재 x
# 진행상황 : 521/826
# 식당 존재 x
# 진행상황 : 522/826
# 식당 존재 x
# 진행상황 : 523/826
# 식당 존재 x
# 진행상황 : 524/826
# 식당 존재 x
# 진행상황 : 525/826
# 식당 존재 x
# 진행상황 : 526/826
# 식당 존재 x
# 진행상황 : 527/826
# 식당 존재 x
# 진행상황 : 528/826
# 식당 존재 x
# 진행상황 : 529/826
# 식당 존재 x
# 진행상황 : 530/826
# 식당 존재 x
# 진행상황 : 531/826
# 식당 존재 x
# 진행상황 : 532/826
# 식당 존재 x
# 진행상황 : 533/826
# 식당 존재 x
# 진행상황 : 534/826
# 식당 존재 x
# 진행상황 : 535/826
# 식당 존재 x
# 진행상황 : 536/826
# 식당 존재 x
# 진행상황 : 537/826
# 식당 존재 x
# 진행상황 : 538/826
# 식당 존재 x
# 진행상황 : 539/826
# 식당 존재 x
# 진행상황 : 540/826
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a363dfa393a7> in <module>
#      16     driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
#      17     searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
# ---> 18     searchbox.send_keys(item)
#      19     time.sleep(2)
#      20     searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
#
# AttributeError: 'NoneType' object has no attribute 'send_keys'

# %%
rating_df
# Out:
#        UserID       ItemID Rating    Timestamp
# 0      vheqgi     도곡역 홈스테드     1점  2021.05.03.
# 1     13vvrgv     도곡역 홈스테드     1점  2021.04.04.
# 2      qg6i7i     도곡역 홈스테드     1점  2019.03.15.
# 3      n2m5vd     도곡역 홈스테드     5점  2018.06.16.
# 4      8vkcle     도곡역 홈스테드     3점  2016.06.20.
# ...       ...          ...    ...          ...
# 1296           압구정로데오역 밀라노     5점  2017.12.23.
# 1297   g7jf8h     한티역 아마스빈     5점  2021.05.03.
# 1298  15g4imj     한티역 아마스빈     5점  2021.02.03.
# 1299   ao678a     한티역 아마스빈     5점  2020.10.20.
# 1300   t2j7an     한티역 아마스빈     5점  2020.10.13.
#
# [1301 rows x 4 columns]

# %%
img_elem
# Out:
#            ItemID img_url
# 0        도곡역 홈스테드    None
# 1        도곡역 홈스테드    None
# 2        도곡역 홈스테드    None
# 3        도곡역 홈스테드    None
# 4        도곡역 홈스테드    None
# ...           ...     ...
# 1296  압구정로데오역 밀라노    None
# 1297     한티역 아마스빈    None
# 1298     한티역 아마스빈    None
# 1299     한티역 아마스빈    None
# 1300     한티역 아마스빈    None
#
# [1301 rows x 2 columns]

# %%
data
# Out:
#           상호명 상권업종중분류명     상권업종소분류명                 도로명주소         역명  \
# 3       노란고무줄   커피점/카페  커피전문점/카페/다방     서울특별시 강남구 선릉로 424      분당 한티
# 7        홈스테드   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 언주로30길 39      분당 도곡
# 11      Manna   커피점/카페     생과일주스전문점     서울특별시 강남구 광평로 280      분당 수서
# 12       스타벅스   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 선릉로64길 18      분당 한티
# 13      커피팩토리   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 도산대로50길 9    분당 강남구청
# ...       ...      ...          ...                   ...        ...
# 4578     총알커피   커피점/카페  커피전문점/카페/다방  서울특별시 성동구 왕십리로5길 9-2     분당 서울숲
# 4592    컴포즈커피   커피점/카페  커피전문점/카페/다방   서울특별시 강남구 선릉로90길 56      분당 한티
# 4593  스테이지246   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 언주로130길 12    분당 강남구청
# 4594       카페   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 언주로172길 36  분당 압구정로데오
# 4595      MMN   커피점/카페  커피전문점/카페/다방  서울특별시 강남구 도산대로66길 39    분당 강남구청
#
#               거리                                카카오url       역            검색어
# 3     547.173123                                   NaN      한티      한티역 노란고무줄
# 7     243.138693  https://place.map.kakao.com/18780447      도곡       도곡역 홈스테드
# 11    139.233515                                  None      수서      수서역 Manna
# 12    149.558597  https://place.map.kakao.com/22178753      한티       한티역 스타벅스
# 13    509.770567  https://place.map.kakao.com/27513867    강남구청    강남구청역 커피팩토리
# ...          ...                                   ...     ...            ...
# 4578  204.699780                                   NaN     서울숲      서울숲역 총알커피
# 4592  597.839979                                   NaN      한티      한티역 컴포즈커피
# 4593  550.784894                                   NaN    강남구청  강남구청역 스테이지246
# 4594  531.075407                                   NaN  압구정로데오     압구정로데오역 카페
# 4595  385.669093                                   NaN    강남구청      강남구청역 MMN
#
# [826 rows x 9 columns]

# %%
img_elem
# Out:
#            ItemID img_url
# 0        도곡역 홈스테드    None
# 1        도곡역 홈스테드    None
# 2        도곡역 홈스테드    None
# 3        도곡역 홈스테드    None
# 4        도곡역 홈스테드    None
# ...           ...     ...
# 1296  압구정로데오역 밀라노    None
# 1297     한티역 아마스빈    None
# 1298     한티역 아마스빈    None
# 1299     한티역 아마스빈    None
# 1300     한티역 아마스빈    None
#
# [1301 rows x 2 columns]

# %%
rating_df
# Out:
#        UserID       ItemID Rating    Timestamp
# 0      vheqgi     도곡역 홈스테드     1점  2021.05.03.
# 1     13vvrgv     도곡역 홈스테드     1점  2021.04.04.
# 2      qg6i7i     도곡역 홈스테드     1점  2019.03.15.
# 3      n2m5vd     도곡역 홈스테드     5점  2018.06.16.
# 4      8vkcle     도곡역 홈스테드     3점  2016.06.20.
# ...       ...          ...    ...          ...
# 1296           압구정로데오역 밀라노     5점  2017.12.23.
# 1297   g7jf8h     한티역 아마스빈     5점  2021.05.03.
# 1298  15g4imj     한티역 아마스빈     5점  2021.02.03.
# 1299   ao678a     한티역 아마스빈     5점  2020.10.20.
# 1300   t2j7an     한티역 아마스빈     5점  2020.10.13.
#
# [1301 rows x 4 columns]

# %%
review_elem
# Out:
#            ItemID                                             review
# 0        도곡역 홈스테드                                 기분 잡치고 싶은사람에게 추천여~
# 1        도곡역 홈스테드  커피에 크레마는 실종이고...  주인장인지 직원인지는 모르겠지만  싸가지는 밥말아 ...
# 2        도곡역 홈스테드  커피는 정말 맛있는데 직원인지 주인인지 일하시는 분이 너무 불친절해서 다시는 안오고...
# 3        도곡역 홈스테드                                               최고예요
# 4        도곡역 홈스테드                                          늦게까지해서 좋다
# ...           ...                                                ...
# 1296  압구정로데오역 밀라노                                               최고예요
# 1297     한티역 아마스빈                                               최고예요
# 1298     한티역 아마스빈  넘 마싯쏘용 여자 직원분 너무 친절하세요 얼그레이 밀크티 향이 진해서 망설이고 있었...
# 1299     한티역 아마스빈                                딸기가 최고..추억이 많은 아마스빈
# 1300     한티역 아마스빈  고딩때부터 밥먹고 아마스빈가는거 거의 공식임 매장좁은데 알바분들 친절하시고 좋음 근...
#
# [1301 rows x 2 columns]

# %%
img_elem.head()
# Out:
#      ItemID img_url
# 0  도곡역 홈스테드    None
# 1  도곡역 홈스테드    None
# 2  도곡역 홈스테드    None
# 3  도곡역 홈스테드    None
# 4  도곡역 홈스테드    None

# %%
ItemID_elem = rating_df['ItemID'].unique()

for k in range(len(ItemID_elem)) :
    User_ID_elem = rating_df.loc[rating_df['ItemID'] == ItemID_elem[k]]
    Uder_ID_elem = User_ID_elem[['UserID','ItemID']]
print(User_ID_elem)





ItemID_elem = img_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_img_elem = img_elem.loc[img_elem['ItemID'] == ItemID_elem[j]]
print(item_img_elem)



ItemID_elem = review_elem['ItemID'].unique()
for j in range(len(ItemID_elem)) :
    item_review_elem = review_elem.loc[review_elem['ItemID'] == ItemID_elem[j]]
print(item_review_elem)
# Out:
#        UserID    ItemID Rating    Timestamp
# 1297   g7jf8h  한티역 아마스빈     5점  2021.05.03.
# 1298  15g4imj  한티역 아마스빈     5점  2021.02.03.
# 1299   ao678a  한티역 아마스빈     5점  2020.10.20.
# 1300   t2j7an  한티역 아마스빈     5점  2020.10.13.
#         ItemID img_url
# 1297  한티역 아마스빈    None
# 1298  한티역 아마스빈    None
# 1299  한티역 아마스빈    None
# 1300  한티역 아마스빈    None
#         ItemID                                             review
# 1297  한티역 아마스빈                                               최고예요
# 1298  한티역 아마스빈  넘 마싯쏘용 여자 직원분 너무 친절하세요 얼그레이 밀크티 향이 진해서 망설이고 있었...
# 1299  한티역 아마스빈                                딸기가 최고..추억이 많은 아마스빈
# 1300  한티역 아마스빈  고딩때부터 밥먹고 아마스빈가는거 거의 공식임 매장좁은데 알바분들 친절하시고 좋음 근...

# %%
rating_df.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin_cafe(540).csv')

# %%
User_ID_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin_cafe_User(540).csv')
item_img_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin_cafe_img(540).csv')
item_review_elem.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/llineSuin_cafe_review(540).csv')

# %%
ItemID_elem = rating_df['ItemID'].unique()
len(ItemID_elem)
# Out:
# 115

# %%
data.to_csv('C:/Users/정예림/Desktop/추천시스템 프로젝트/data/lineSuin(540)url.csv')
